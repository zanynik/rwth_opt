# %%
import pandas as pd
from gurobipy import *
import matplotlib.pyplot as plt
import math
import numpy as np
import datetime as dt

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.max_columns', 500)

# %%
booking = pd.read_excel("/media/luckshan/New Volume/AirCargo/Ab-Ovo Project/Ab Ovo Data/Booking_new.xlsx")
bd_zones = pd.read_excel("/media/luckshan/New Volume/AirCargo/Ab-Ovo Project/Ab Ovo Data/BreakDownZones.xlsx")
dz_to_bd = pd.read_excel("/media/luckshan/New Volume/AirCargo/Ab-Ovo Project/Ab Ovo Data/DistanceMatrixDropZoneToBreakDownZone.xlsx")
drop_zones = pd.read_excel("/media/luckshan/New Volume/AirCargo/Ab-Ovo Project/Ab Ovo Data/DropZones.xlsx")
bu_zones = pd.read_excel("/media/luckshan/New Volume/AirCargo/Ab-Ovo Project/Ab Ovo Data/Outbound.xlsx", sheet_name='BU Zones')
bu_zones_workstations = pd.read_excel("/media/luckshan/New Volume/AirCargo/Ab-Ovo Project/Ab Ovo Data/Outbound.xlsx", sheet_name='WorkStation')
bu_zones_to_flight = pd.read_excel("/media/luckshan/New Volume/AirCargo/Ab-Ovo Project/Ab Ovo Data/Outbound.xlsx", sheet_name='FlightNumber-BUZone')
flight_default_processing = pd.read_excel("/media/luckshan/New Volume/AirCargo/Ab-Ovo Project/Ab Ovo Data/Outbound.xlsx", sheet_name='DefaultProcessingTime')
flight_pre_processing = pd.read_excel("/media/luckshan/New Volume/AirCargo/Ab-Ovo Project/Ab Ovo Data/Outbound.xlsx", sheet_name='Pre-ProcessingBufferTime')

# %%
flight_pre_processing['Weekday'].unique()
# Out:
# array(['*', 7, 6], dtype=object)

# %%
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
all_days_pre = flight_pre_processing[flight_pre_processing.Weekday=='*']

# %%
all_days_pro = []
for d in days:
    for index, row in all_days_pre.iterrows():
        all_days_pro.append((row['FlightNumber'], row['Weekday'], row['PreProcessingBufferTime'], d))

all_days_pro1 = pd.DataFrame(all_days_pro, columns=('FlightNumber', 'Weekday', 'PreProcessingBufferTime', 'day'))
all_days_pro1 = all_days_pro1.sort_values(by=['FlightNumber'])

# %%
sunday_days_pre = flight_pre_processing[flight_pre_processing.Weekday==7]

# %%
sunday_days_pro = []
for d in ['Sunday']:
    for index, row in sunday_days_pre.iterrows():
        sunday_days_pro.append((row['FlightNumber'], row['Weekday'], row['PreProcessingBufferTime'], d))

sunday_days_pro1 = pd.DataFrame(sunday_days_pro, columns=('FlightNumber', 'Weekday', 'PreProcessingBufferTime', 'day'))
sunday_days_pro1 = sunday_days_pro1.sort_values(by=['FlightNumber'])

# %%
saturday_days_pre = flight_pre_processing[flight_pre_processing.Weekday==6]

# %%
saturday_days_pro = []
for d in ['Saturday']:
    for index, row in saturday_days_pre.iterrows():
        saturday_days_pro.append((row['FlightNumber'], row['Weekday'], row['PreProcessingBufferTime'], d))

saturday_days_pro1 = pd.DataFrame(saturday_days_pro, columns=('FlightNumber', 'Weekday', 'PreProcessingBufferTime', 'day'))
saturday_days_pro1 = saturday_days_pro1.sort_values(by=['FlightNumber'])

# %%
flight_pre_processing_all = all_days_pro1.append(sunday_days_pro1)
flight_pre_processing_all = flight_pre_processing_all.append(saturday_days_pro1)

# %%
flight_pre_processing_all[['Pre_h','Pre_m','Pre_s']] = pd.DataFrame([(x.hour, x.minute, x.second) for x in flight_pre_processing_all['PreProcessingBufferTime']])

# %%
flight_pre_processing_all['flight_pre_id'] = flight_pre_processing_all['FlightNumber'].astype(str) + "_" + flight_pre_processing_all['day']

# %%
flight_pre_processing_all.head()
# Out:
#     FlightNumber Weekday PreProcessingBufferTime       day  Pre_h  Pre_m  Pre_s flight_pre_id
# 0              3       *                00:10:00    Monday      0     10      0      3_Monday
# 24             3       *                00:10:00    Sunday      0     25      0      3_Sunday
# 4              3       *                00:10:00   Tuesday      0     10      0     3_Tuesday
# 20             3       *                00:10:00  Saturday      0     15      0    3_Saturday
# 16             3       *                00:10:00    Friday      0     15      0      3_Friday

# %%
flight_default_processing[['default_h','default_m','default_s']] = pd.DataFrame([(x.hour, x.minute, x.second) for x in flight_default_processing['DefaultProcessingTime']])

# %%
bu_zones_to_flight[['transport_dist_h','transport_dist_m','transport_dist_s']] = pd.DataFrame([(x.hour, x.minute, x.second) for x in bu_zones_to_flight['TransportationDistance']])

# %%
bu_zones_to_flight.shape
# Out:
# (82, 6)

# %%
bu_zones_to_flight = bu_zones_to_flight.merge(flight_default_processing, on=['FlightNumber'])

# %%
bu_zones_to_flight.head()
# Out:
#    FlightNumber  BU Zone TransportationDistance  transport_dist_h  transport_dist_m  transport_dist_s DefaultProcessingTime  default_h  default_m  default_s
# 0             1  BU FT-1               00:05:00                 0                 5                 0              00:15:00          0         15          0
# 1             2  BU FT-1               00:11:00                 0                11                 0              00:15:00          0         15          0
# 2             3  BU FT-1               00:19:00                 0                19                 0              00:10:00          0         10          0
# 3             4  BU FT-1               00:24:00                 0                24                 0              00:25:00          0         25          0
# 4             5  BU FT-1               00:05:00                 0                 5                 0              00:15:00          0         15          0

# %%
dz = list(drop_zones['Name'].unique())
break_down_zones = list(bd_zones['Name'].unique())

# %%
dz_to_bd[['h','m','s']] = pd.DataFrame([(x.hour, x.minute, x.second) for x in dz_to_bd['TransportDuration']])
bd_zones[['handling_h','handling_m','handling_s']] = pd.DataFrame([(x.hour, x.minute, x.second) for x in bd_zones['HandlingTimePerULD']])
bd_zones[['transport_WH_h','transport_WH_m','transport_WH_s']] = pd.DataFrame([(x.hour, x.minute, x.second) for x in bd_zones['TransportationTimeToWH']])

# %%
booking['key_shipment_id_arrival_date'] = booking['Shipment ID'].astype(str) + booking['ShipmentArrivalDateUTC'].astype(str)
booking = booking.drop_duplicates('key_shipment_id_arrival_date')

# %%
booking = booking[booking.TotalWeight<=400]

# %%
#####################################################################################
#Handling multiple ULDs having same number arriving less than 4 hours

# %%
uld_number_times = booking[['ShipmentArrivalDateUTC', 'ArrivalULDNumber']]
uld_number_times['id'] = booking['ShipmentArrivalDateUTC'].astype(str) + '_' + booking['ArrivalULDNumber'].astype(str)
uld_number_times = uld_number_times.drop_duplicates('id')
uld_number_times.shape
# Out:
# /home/luckshan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (312, 3)

# %%
uld_number_times['count_uld_number'] = 1

# %%
unique_uld_count_by_number = uld_number_times.groupby(['ArrivalULDNumber']).agg({"count_uld_number":"count"}).rename(columns={"count_uld_number":"Count"}).reset_index()
multiple_uld_numbers = unique_uld_count_by_number[unique_uld_count_by_number.Count>1]

# %%
multiple_uld_number_and_times = uld_number_times[uld_number_times['ArrivalULDNumber'].isin((multiple_uld_numbers['ArrivalULDNumber'].unique()))]
multiple_uld_number_and_times = multiple_uld_number_and_times.sort_values(by=['ArrivalULDNumber', 'ShipmentArrivalDateUTC'])
multiple_uld_number_and_times['arrival_time'] = pd.to_datetime(multiple_uld_number_and_times['ShipmentArrivalDateUTC'])
multiple_uld_number_and_times['diff'] = multiple_uld_number_and_times.sort_values(by=['ArrivalULDNumber', 'arrival_time']).groupby('ArrivalULDNumber')['arrival_time'].diff()
multiple_ULD_arriving_below_4_hours = list(multiple_uld_number_and_times[multiple_uld_number_and_times['diff'].notnull() & (multiple_uld_number_and_times['diff'] < pd.Timedelta(4, unit='h'))]['ArrivalULDNumber'].unique())
booking = booking[~booking['ArrivalULDNumber'].isin(multiple_ULD_arriving_below_4_hours)]

# %%
#######################################################################################

# %%
# Filtering shipments arriving after departure
booking['Shipment_arrival_date_time'] = pd.to_datetime(booking['ShipmentArrivalDateUTC'])
booking = booking[booking.ShipmentDepartureDateUTC != '2018-10-24T26:20:00']
booking['Shipment_departure_date_time'] = pd.to_datetime(booking['ShipmentDepartureDateUTC'])
booking['Shipment_duration'] = booking['Shipment_departure_date_time']-booking['Shipment_arrival_date_time']
booking = booking[booking.Shipment_duration>pd.Timedelta(0)]

# %%
#######################################################################################

# %%
booking['count_shipments'] = 1
multple_dropzone_check = booking.pivot_table(index=['ArrivalULDNumber', 'Shipment_arrival_date_time'], columns='DropZone', values= 'count_shipments').reset_index()
multple_dropzone_check = multple_dropzone_check.fillna(0)
multple_dropzone_check['Two_different_dropzones_check'] = multple_dropzone_check['DZ NML-1'] + multple_dropzone_check['DZ NRML-1'] + multple_dropzone_check['DZ NRML-2']
unique_dropzone_check = multple_dropzone_check[multple_dropzone_check.Two_different_dropzones_check==1.0]
two_drop_zones = multple_dropzone_check[multple_dropzone_check.Two_different_dropzones_check>1.0]

# %%
two_drop_zones['unique_id'] = two_drop_zones['ArrivalULDNumber'].astype(str) + '_' + (pd.to_timedelta(two_drop_zones['Shipment_arrival_date_time']).astype('timedelta64[m]').astype(int).astype(str))
# Out:
# /home/luckshan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Passing datetime64-dtype data to TimedeltaIndex is deprecated, will raise a TypeError in a future version
#   """Entry point for launching an IPython kernel.
# /home/luckshan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dz_to_bd['DropZoneName_filter'] = dz_to_bd['DropZoneName'].apply(lambda x: x.split('-')[0]).str[3:]
dz_to_bd['bd_type1'] = dz_to_bd['BreakDownZoneName'].apply(lambda x: x.split(' ')[1])
dz_to_bd.loc[dz_to_bd['BreakDownZoneName'] == 'B BD NRML-1', 'bd_type1'] = "NRML-1"
dz_to_bd.loc[dz_to_bd['BreakDownZoneName'] == 'B BD NRML-2', 'bd_type1'] = "NRML-2"
dz_to_bd['bd_type'] =  dz_to_bd['bd_type1'].apply(lambda x: x.split('-')[0])
dz_to_bd['check'] = np.where(dz_to_bd['DropZoneName_filter']==dz_to_bd['bd_type'], 1, 0)
dz_to_bd = dz_to_bd[dz_to_bd['check']==1]
dz_to_bd = dz_to_bd[['BreakDownZoneName', 'DropZoneName', 'TransportDuration', 'h', 'm', 's']]

# %%
dz_ship_data = booking[['DropZone','ArrivalULDNumber', 'ShipmentArrivalDateUTC']]
dz_ship_data['unique_key'] =  dz_ship_data['DropZone'].astype(str) + '_' + dz_ship_data['ArrivalULDNumber'].astype(str) + '_' + dz_ship_data['ShipmentArrivalDateUTC'].astype(str)
dz_ship_data = dz_ship_data.drop_duplicates('unique_key')
dz_ship_data = dz_ship_data[['DropZone', 'ArrivalULDNumber', 'ShipmentArrivalDateUTC']]
# Out:
# /home/luckshan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
uld_bd_data = pd.merge(dz_ship_data, dz_to_bd, left_on='DropZone', right_on='DropZoneName')

# %%
uld_bd_data['key'] = uld_bd_data['DropZone'].astype(str) + '_' + uld_bd_data['ArrivalULDNumber'].astype(str) + '_' + uld_bd_data['ShipmentArrivalDateUTC'].astype(str) + '_' + uld_bd_data['BreakDownZoneName'].astype(str)
uld_bd_data = uld_bd_data.drop_duplicates('key')

# %%
uld_bd_data['Shipment_arrival_date_time'] = pd.to_datetime(uld_bd_data['ShipmentArrivalDateUTC'])

# %%
#Getting BU workstations count
bu_workstation_count = bu_zones_workstations.groupby(['Name']).count().reset_index()
bu_workstation_count.columns = ['Name', 'Count']

# %%
bu_zones_data = pd.merge(bu_zones_to_flight, bu_zones, left_on='BU Zone', right_on='Name')
bu_zone_all = pd.merge(bu_zones_data, bu_workstation_count, left_on='BU Zone', right_on='Name')

# %%
bu_zone_all[['handling_ULD_h','handling_ULD_m','handling_ULD_s']] = pd.DataFrame([(x.hour, x.minute, x.second) for x in bu_zone_all['HandlingTimePerULD']])
bu_zone_all[['transport_WH_h','transport_WH_m','transport_WH_s']] = pd.DataFrame([(x.hour, x.minute, x.second) for x in bu_zone_all['TransportationTimeToWH']])

# %%
booking.head()
# Out:
#     Shipment ID FlightDate ShipmentArrivalDateUTC ProductName ShipmentOrigin ShipmentDestination CarrierCode  Priority   DropZone FlightNumberArrival  SerialNumber  ArrivalULDNumber  Pieces  Weight  Volume BookingStatus WeighCMMit VolumeUnit  TotalVolume  TotalWeight  TotalNumberOfPieces FlightNumberDeparture ShipmentDepartureDateUTC     key_shipment_id_arrival_date Shipment_arrival_date_time Shipment_departure_date_time Shipment_duration  count_shipments
# 0  020-77215633 2018-10-23    2018-10-23T06:10:00        NRML            BBB                 ACC          ZZ     False  DZ NRML-2                   1             1             21231       1    26.2    0.08             C          K          B         0.08         26.2                    1                     3      2018-10-25T05:15:00  020-772156332018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-25 05:15:00   1 days 23:05:00                1
# 1  020-77215515 2018-10-23    2018-10-23T06:10:00        NRML            BBB                 ADD          ZZ     False  DZ NRML-2                   1             1             21231       1     5.5    0.02             C          K          B         0.02          5.5                    1                     4      2018-10-27T13:45:00  020-772155152018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-27 13:45:00   4 days 07:35:00                1
# 2  020-84100306 2018-10-23    2018-10-23T06:10:00         NML            BBB                 AGG          ZZ     False   DZ NML-1                   1             1             21231       1     2.6    0.01             C          K          B         0.01          2.6                    1                     7      2018-10-24T21:20:00  020-841003062018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-24 21:20:00   1 days 15:10:00                1
# 3  020-82036091 2018-10-23    2018-10-23T06:10:00        NRML            BBB                 AII          ZZ     False  DZ NRML-2                   1             1             21231       1     1.7    0.01             C          K          B         0.01          1.7                    1                     9      2018-10-27T17:20:00  020-820360912018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-27 17:20:00   4 days 11:10:00                1
# 4  020-84368815 2018-10-23    2018-10-23T06:10:00        NRML            BBB                 CCC          ZZ     False  DZ NRML-2                   1             1             21231       1    22.6    0.26             C          K          B         0.26         22.6                    1                    46      2018-10-24T23:00:00  020-843688152018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-24 23:00:00   1 days 16:50:00                1

# %%
#Creating booking_new variable for future use
booking['build_up_arrival_time'] =  booking['Shipment_arrival_date_time'] #+ np.timedelta64(2, 'h')
booking['build_up_finish_time'] =  booking['Shipment_departure_date_time'] #- np.timedelta64(1, 'h')
booking_new = booking[['Shipment ID','ProductName', 'Priority', 'DropZone', 'ArrivalULDNumber', 'Pieces', 'Weight', 'TotalWeight',
         'FlightNumberDeparture', 'key_shipment_id_arrival_date', 'Shipment_arrival_date_time', 'Shipment_departure_date_time',
         'Shipment_duration', 'build_up_arrival_time', 'build_up_finish_time']]

# %%
booking_new = pd.merge(booking_new, bu_zone_all, left_on='FlightNumberDeparture', right_on='FlightNumber')

# %%
booking_new[['ULD_handling_h','ULD_handling_m','ULD_handling_s']] = pd.DataFrame([(x.hour, x.minute, x.second) for x in booking_new['HandlingTimePerULD']])
booking_new['arrival_date'] = booking_new['Shipment_arrival_date_time'].dt.normalize()
booking_new['departure_date'] = booking_new['Shipment_departure_date_time'].dt.normalize()

# %%
# DataFrame used in  BD zone
#sample_shipments = booking_new.iloc[98:118,:]
# sample_shipments = booking_new[booking_new['ArrivalULDNumber'].isin(list([34842, 34222, 92870, 21231, 49815, 51228, 59243]))]
# sample_shipments = booking_new[booking_new['ArrivalULDNumber'].isin(list([34842, 34222, 92870]))]
# sample_shipments = booking_new[booking_new['ArrivalULDNumber'].isin(list([34842, 34222,92870, 21231, 49815, 59243]))]
# sample_shipments = booking_new[booking_new['ArrivalULDNumber'].isin(list([51228]))]
sample_shipments = booking_new

# %%
sample_shipments['Shipment_duration_minutes'] = (sample_shipments['Shipment_duration'] / np.timedelta64(1, 'm')).astype(int)
sample_shipments['Shipment_arrival_time_minutes'] = pd.to_timedelta(sample_shipments['Shipment_arrival_date_time']).astype('timedelta64[m]').astype(int)
sample_shipments['Shipment_departure_time_minutes'] = pd.to_timedelta(sample_shipments['Shipment_departure_date_time']).astype('timedelta64[m]').astype(int)
# Out:
# /home/luckshan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: Passing datetime64-dtype data to TimedeltaIndex is deprecated, will raise a TypeError in a future version
#
# /home/luckshan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: Passing datetime64-dtype data to TimedeltaIndex is deprecated, will raise a TypeError in a future version
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
new = sample_shipments[['DropZone','ArrivalULDNumber', 'Shipment_arrival_date_time', 'Shipment_duration_minutes','Shipment_arrival_time_minutes', 'Shipment_departure_time_minutes']]
df_merge= pd.merge(uld_bd_data, new, on=['DropZone','ArrivalULDNumber', 'Shipment_arrival_date_time'])
df_merge = df_merge.drop_duplicates('key')
bd_capacity = bd_zones[['Name','NumberOfWorkstations', 'handling_m']]
df_merge1 = df_merge.merge(bd_capacity, left_on='BreakDownZoneName', right_on='Name')

# %%
#BD process needed to to be completed with in 60 minutes
df_merge1['one_hour_duration'] = 60

# %%
df_merge1['unique_id'] = df_merge1['ArrivalULDNumber'].astype(str) + '_' + df_merge1['Shipment_arrival_time_minutes'].astype(str)

# %%
two_drop_zones_ULD_Numbers = list(two_drop_zones['unique_id'].unique())
#two_drop_zones_ULD_Numbers = list(two_drop_zones[two_drop_zones['ArrivalULDNumber'].isin([34842, 34222, 92870, 21231, 49815, 51228, 59243])]['unique_id'].unique())

# %%
uld_uniqueid_list = list(df_merge1['unique_id'].unique())

# %%
ArrivalULDNumber_list = list(df_merge1['ArrivalULDNumber'].unique())
BreakDownZoneName_list = list(df_merge1['BreakDownZoneName'].unique())

# %%
#############################################################################################################
##################################################################################################################
###############################################################################################################################################

# %%
sample_shipments['day_name'] = sample_shipments['departure_date'].apply(lambda x: dt.datetime.strftime(x, '%A'))

# %%
sample_shipments['flight_pre_id'] = sample_shipments['FlightNumber'].astype(str) + '_' + sample_shipments['day_name']

# %%
sample_shipments = sample_shipments.merge(flight_pre_processing_all, on=['flight_pre_id'] , how='left')

# %%
sample_shipments = sample_shipments.fillna(0)
# Out:
# /home/luckshan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Passing integers to fillna is deprecated, will raise a TypeError in a future version.  To retain the old behavior, pass pd.Timedelta(seconds=n) instead.
#   """Entry point for launching an IPython kernel.

# %%
sample_shipments['Pre_m'].unique()
# Out:
# array([10.,  0., 15.])

# %%
sample_shipments['FlightNumber_y'] = sample_shipments['FlightNumber_y'].astype('int64')
sample_shipments['Pre_h'] = sample_shipments['Pre_h'].astype('int64')
sample_shipments['Pre_m'] = sample_shipments['Pre_m'].astype('int64')
sample_shipments['Pre_s'] = sample_shipments['Pre_s'].astype('int64')

# %%
sample_shipments['new_departure_time'] = sample_shipments['Shipment_departure_time_minutes'] - sample_shipments['transport_dist_m'] - sample_shipments['default_m'] - sample_shipments['Pre_m'] - sample_shipments['handling_ULD_m'] - sample_shipments['transport_WH_m'] -30

# %%
sample_shipments['Shipment_departure_time_minutes'] = sample_shipments['new_departure_time']

# %%
booking_new_BU = sample_shipments

# %%
booking_new_BU['shipment_ID'] = range(1, len(booking_new_BU) + 1)
shipment_id_list = list(booking_new_BU['shipment_ID'].unique())

# %%
booking_new_BU.head()
# Out:
#     Shipment ID ProductName  Priority   DropZone  ArrivalULDNumber  Pieces  Weight  TotalWeight  FlightNumberDeparture     key_shipment_id_arrival_date Shipment_arrival_date_time Shipment_departure_date_time Shipment_duration build_up_arrival_time build_up_finish_time  FlightNumber_x  BU Zone TransportationDistance  transport_dist_h  transport_dist_m  transport_dist_s DefaultProcessingTime  default_h  default_m  default_s   Name_x HandlingTimePerULD TransportationTimeToWH   Name_y  Count  handling_ULD_h  handling_ULD_m  handling_ULD_s  transport_WH_h  transport_WH_m  transport_WH_s  ULD_handling_h  ULD_handling_m  ULD_handling_s arrival_date departure_date  Shipment_duration_minutes  Shipment_arrival_time_minutes  Shipment_departure_time_minutes  day_name flight_pre_id  FlightNumber_y Weekday PreProcessingBufferTime       day  Pre_h  Pre_m  Pre_s  new_departure_time  shipment_ID
# 0  020-77215633        NRML     False  DZ NRML-2             21231       1    26.2         26.2                      3  020-772156332018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-25 05:15:00   1 days 23:05:00   2018-10-23 06:10:00  2018-10-25 05:15:00               3  BU FT-1               00:19:00                 0                19                 0              00:10:00          0         10          0  BU FT-1           00:24:00               00:50:00  BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-23     2018-10-25                       2825                       25671250                         25673932  Thursday    3_Thursday               3       *                00:10:00  Thursday      0     10      0            25673932            1
# 1  020-77215994        NRML     False  DZ NRML-1             76631       1     6.5          6.5                      3  020-772159942018-10-23T20:10:00        2018-10-23 20:10:00          2018-10-25 05:15:00   1 days 09:05:00   2018-10-23 20:10:00  2018-10-25 05:15:00               3  BU FT-1               00:19:00                 0                19                 0              00:10:00          0         10          0  BU FT-1           00:24:00               00:50:00  BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-23     2018-10-25                       1985                       25672090                         25673932  Thursday    3_Thursday               3       *                00:10:00  Thursday      0     10      0            25673932            2
# 2  020-88154710        NRML     False  DZ NRML-1             59245       1    10.5         10.5                      3  020-881547102018-10-23T19:05:00        2018-10-23 19:05:00          2018-10-25 05:15:00   1 days 10:10:00   2018-10-23 19:05:00  2018-10-25 05:15:00               3  BU FT-1               00:19:00                 0                19                 0              00:10:00          0         10          0  BU FT-1           00:24:00               00:50:00  BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-23     2018-10-25                       2050                       25672025                         25673932  Thursday    3_Thursday               3       *                00:10:00  Thursday      0     10      0            25673932            3
# 3  020-88154710        NRML     False  DZ NRML-1             44942       1    10.5         10.5                      3  020-881547102018-10-24T15:40:00        2018-10-24 15:40:00          2018-10-25 05:15:00   0 days 13:35:00   2018-10-24 15:40:00  2018-10-25 05:15:00               3  BU FT-1               00:19:00                 0                19                 0              00:10:00          0         10          0  BU FT-1           00:24:00               00:50:00  BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-24     2018-10-25                        815                       25673260                         25673932  Thursday    3_Thursday               3       *                00:10:00  Thursday      0     10      0            25673932            4
# 4  020-77215994        NRML     False  DZ NRML-1             44942       1     6.5          6.5                      3  020-772159942018-10-24T15:40:00        2018-10-24 15:40:00          2018-10-25 05:15:00   0 days 13:35:00   2018-10-24 15:40:00  2018-10-25 05:15:00               3  BU FT-1               00:19:00                 0                19                 0              00:10:00          0         10          0  BU FT-1           00:24:00               00:50:00  BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-24     2018-10-25                        815                       25673260                         25673932  Thursday    3_Thursday               3       *                00:10:00  Thursday      0     10      0            25673932            5

# %%
#Data used for BU process 'sample_shipments_bu'
sample_shipments_bu = booking_new_BU

# %%
sample_shipments_bu['Shipment_departure_time_minutes'].unique()
# Out:
# array([25673932, 25677312, 25673472, 25677559, 25673565, 25675474,
#        25674457, 25673597, 25676223, 25677043, 25674729, 25677413,
#        25673325, 25674483, 25676219, 25674972, 25673742, 25674620,
#        25675037, 25671904, 25673415, 25673332, 25673400, 25675163,
#        25675945, 25674459, 25672496, 25673936, 25681136, 25673800,
#        25673776, 25675721, 25674906, 25674325, 25674002, 25674296,
#        25673306, 25674866, 25674015, 25672644, 25673465, 25673456,
#        25673999, 25673890, 25674097, 25673355, 25674794, 25673370,
#        25673566, 25675040, 25674427, 25673981, 25675737, 25673409,
#        25674135, 25673544, 25674901, 25673972, 25673436, 25673270,
#        25673873, 25676260, 25674166, 25674910, 25674789, 25673149,
#        25679723, 25672563, 25673220, 25673600, 25674346, 25673116,
#        25676418, 25674797, 25674541, 25680842, 25672564, 25675623,
#        25674793, 25676089, 25672018])

# %%
sample_shipments_bu['unique_id'] = sample_shipments_bu['ArrivalULDNumber'].astype(str) + '_' + sample_shipments_bu['Shipment_arrival_time_minutes'].astype(str)

# %%
ArrivalULDNumber_list = list(sample_shipments_bu['ArrivalULDNumber'].unique())
filghts_list = list(sample_shipments_bu['FlightNumberDeparture'].unique())
bu_zones_list = list(sample_shipments_bu['Name_x'].unique())

# %%
##################################################################################
#####################################################################################
#######################################################################################

# %%
# Full Model

# %%
#import datetime
print(dt.datetime.now())
# Out:
# 2019-07-02 00:00:41.931702

# %%
model = Model('Full model')
# Out:
# Academic license - for non-commercial use only

# %%
#Discretisation has been done based on each BD zone handling times
x = {}
for i in uld_uniqueid_list:
    BreakDownZoneName_list1 = list(df_merge1[df_merge1.unique_id==i]['BreakDownZoneName'])
    #print(BreakDownZoneName_list1)
    for j in BreakDownZoneName_list1:
        #print(int(i),str(j))
        new_check = df_merge1[(df_merge1.unique_id==i) & (df_merge1.BreakDownZoneName==j)]
        min_time = min(list(df_merge1[df_merge1.BreakDownZoneName==j]['Shipment_arrival_time_minutes'].unique()))
        arr = list(new_check['Shipment_arrival_time_minutes'].unique())[0]
            #print(arr,"--",i)
        shipment_arrival_duation_minutes_loop = list(new_check['one_hour_duration'].unique())[0] #list(new_check['Shipment_duration_minutes'].unique())[0]
        handling_minutes = list(new_check['handling_m'].unique())[0]
            #print(shipment_arrival_time_minutes_loop, handling_minutes)
        t_start = (min_time + (math.ceil((arr-min_time)/handling_minutes)*handling_minutes))
            #print(arr,"-----",t_start)
        #if(i == '51228_25671360'):   
            #print(t_start)
        for k in range(t_start, t_start+shipment_arrival_duation_minutes_loop, handling_minutes):
            x[i,j,k] = model.addVar(vtype=GRB.BINARY)

# %%
z = {}
for i in ArrivalULDNumber_list:
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.ArrivalULDNumber==i]['departure_date'].unique())
    for d in shipment_date_list:
        shipment_list = list(sample_shipments_bu[(sample_shipments_bu.ArrivalULDNumber==i) & (sample_shipments_bu.departure_date==d)]['shipment_ID'])
        #print(shipment_list)
        for l in shipment_list:
        #print(int(i),str(j))
            number_of_ws = sample_shipments_bu[(sample_shipments_bu.ArrivalULDNumber==i) & (sample_shipments_bu.shipment_ID==l)]['Count'].unique()[0]
            shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.ArrivalULDNumber==i) & (sample_shipments_bu.shipment_ID==l)]['Shipment_departure_time_minutes'].unique()[0]
            for m in range(1,number_of_ws+1):
                for t in range(shipment_departure_time_minutes_loop-60, shipment_departure_time_minutes_loop):
                    z[l,m,t] = model.addVar(vtype=GRB.BINARY)

# %%
q = {}
for k in filghts_list:
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.FlightNumberDeparture==k]['departure_date'].unique())
    for d in shipment_date_list:
        ws_list = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Count'].unique()[0]
        shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_departure_time_minutes'].unique()[0]
    #print(shipment_list)
        for m in range(1, ws_list+1):
        #print(int(i),str(j))
            for t in range(shipment_departure_time_minutes_loop-60, shipment_departure_time_minutes_loop):
                q[k,m,t] = model.addVar(vtype=GRB.BINARY)

# %%
#BD Constraints

# %%
# #Handling time of each bd zone take into account for the quicksum
for i in (list(set(uld_uniqueid_list) - set(two_drop_zones_ULD_Numbers))):
    BreakDownZoneName_list1 = list(df_merge1[df_merge1.unique_id==i]['BreakDownZoneName'])
    new_check = df_merge1[(df_merge1.unique_id==i)]
    arr = list(new_check['Shipment_arrival_time_minutes'].unique())[0]
    shipment_arrival_duation_minutes_loop = list(new_check['one_hour_duration'].unique())[0] #list(new_check['Shipment_duration_minutes'].unique())[0]
    #min_time = min(list(df_merge1[df_merge1.BreakDownZoneName.isin(BreakDownZoneName_list1)]['Shipment_arrival_time_minutes'].unique()))
    #t_start = shipment_arrival_time_minutes_loop + (handling_minutes - (shipment_arrival_time_minutes_loop%min_time))
    if(len(BreakDownZoneName_list1)!=0):
        model.addConstr(quicksum(x[i,b,c] for b in BreakDownZoneName_list1 for c in range((min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((arr-min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))), (min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((arr-min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))) +shipment_arrival_duation_minutes_loop, df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m'])) == 1)

# %%
# #Handling time of each bd zone take into account for the quicksum
for i in two_drop_zones_ULD_Numbers:
    #print(i)
    BreakDownZoneName_list1 = list(df_merge1[df_merge1.unique_id==i]['BreakDownZoneName'])
    bd_NML_list = [k for k in BreakDownZoneName_list1 if 'NML' in k]
    bd_NRML_list = [k for k in BreakDownZoneName_list1 if 'NRML' in k]
    #print(BreakDownZoneName_list1)
    #print(bd_NML_list)
    #print(bd_NRML_list)
    new_check = df_merge1[(df_merge1.unique_id==i)]
    arr = list(new_check['Shipment_arrival_time_minutes'].unique())[0]
    #print(arr)
    shipment_arrival_duation_minutes_loop = list(new_check['one_hour_duration'].unique())[0] #list(new_check['Shipment_duration_minutes'].unique())[0]
    #min_time = min(list(df_merge1[df_merge1.BreakDownZoneName.isin(BreakDownZoneName_list1)]['Shipment_arrival_time_minutes'].unique()))
    #t_start = shipment_arrival_time_minutes_loop + (handling_minutes - (shipment_arrival_time_minutes_loop%min_time))
    if(len(bd_NML_list)!=0):
        model.addConstr(quicksum(x[i,b,c] for b in bd_NML_list for c in range((min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((arr-min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))), (min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((arr-min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))) +shipment_arrival_duation_minutes_loop, df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m'])) == 1)
    if(len(bd_NRML_list)!=0):
        model.addConstr(quicksum(x[i,b,c] for b in bd_NRML_list for c in range((min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((arr-min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))), (min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((arr-min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))) +shipment_arrival_duation_minutes_loop, df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m'])) == 1)

# %%
#Precedence of NML before NRML
for i in two_drop_zones_ULD_Numbers:
    #print(i)
    BreakDownZoneName_list1 = list(df_merge1[df_merge1.unique_id==i]['BreakDownZoneName'])
    bd_NML_list = [k for k in BreakDownZoneName_list1 if 'NML' in k]
    bd_NRML_list = [k for k in BreakDownZoneName_list1 if 'NRML' in k]
    #print(BreakDownZoneName_list1)
    #print(bd_NML_list)
    #print(bd_NRML_list)
    new_check = df_merge1[(df_merge1.unique_id==i)]
    arr = list(new_check['Shipment_arrival_time_minutes'].unique())[0]
    #print(arr)
    shipment_arrival_duation_minutes_loop = list(new_check['one_hour_duration'].unique())[0] #list(new_check['Shipment_duration_minutes'].unique())[0]
    #min_time = min(list(df_merge1[df_merge1.BreakDownZoneName.isin(BreakDownZoneName_list1)]['Shipment_arrival_time_minutes'].unique()))
    #t_start = shipment_arrival_time_minutes_loop + (handling_minutes - (shipment_arrival_time_minutes_loop%min_time))
    if((len(bd_NML_list)!=0) & (len(bd_NRML_list)!=0)):
        model.addConstr(quicksum((c+(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))*x[i,b,c] for b in bd_NML_list for c in range((min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((arr-min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))), (min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((arr-min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))) +shipment_arrival_duation_minutes_loop, df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m'])) <= quicksum(c*x[i,b,c] for b in bd_NRML_list for c in range((min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((arr-min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))), (min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((arr-min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))) +shipment_arrival_duation_minutes_loop, df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m'])))

# %%
#BD Assgnment Time constraint
for i in (list(set(uld_uniqueid_list) - set(two_drop_zones_ULD_Numbers))):
    #for j in BreakDownZoneName_list:
        #print(int(i),str(j))
    BreakDownZoneName_list1 = list(df_merge1[df_merge1.unique_id==i]['BreakDownZoneName'])
    new_check = df_merge1[(df_merge1.unique_id==i)]
    arr = list(new_check['Shipment_arrival_time_minutes'].unique())[0]
    shipment_arrival_duation_minutes_loop = list(new_check['one_hour_duration'].unique())[0] #list(new_check['Shipment_duration_minutes'].unique())[0]
    #arrival_time_each_uld = list(new_check['Shipment_arrival_time_minutes'].unique())[0]
    transport_time_each_bd_zone = list(new_check['m'].unique())[0]
    if(len(BreakDownZoneName_list1)!=0):
        model.addConstr(quicksum((c-df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['m'])*x[i,b,c] for b in BreakDownZoneName_list1 for c in range((min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((arr-min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))), (min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((arr-min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))) +shipment_arrival_duation_minutes_loop, df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m'])) >= arr)
        #for k in range(shipment_arrival_duation_minutes_loop):

# %%
#BD Assgnment Time constraint
for i in two_drop_zones_ULD_Numbers:
    #for j in BreakDownZoneName_list:
        #print(int(i),str(j))
    BreakDownZoneName_list1 = list(df_merge1[df_merge1.unique_id==i]['BreakDownZoneName'])
    bd_NML_list = [k for k in BreakDownZoneName_list1 if 'NML' in k]
    new_check = df_merge1[(df_merge1.unique_id==i)]
    arr = list(new_check['Shipment_arrival_time_minutes'].unique())[0]
    shipment_arrival_duation_minutes_loop = list(new_check['one_hour_duration'].unique())[0] #list(new_check['Shipment_duration_minutes'].unique())[0]
    #arrival_time_each_uld = list(new_check['Shipment_arrival_time_minutes'].unique())[0]
    transport_time_each_bd_zone = list(new_check['m'].unique())[0]
    if(len(bd_NML_list)!=0):
        model.addConstr(quicksum((c-df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['m'])*x[i,b,c] for b in bd_NML_list for c in range((min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((arr-min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))), (min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((arr-min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))) +shipment_arrival_duation_minutes_loop, df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m'])) >= arr)
        #for k in range(shipment_arrival_duation_minutes_loop):

# %%
for j in BreakDownZoneName_list:
        #print(int(i),str(j))
    new_check = df_merge1[df_merge1.BreakDownZoneName==j]
    min_time = min(list(new_check['Shipment_arrival_time_minutes'].unique()))
    max_time = max(list(new_check['Shipment_departure_time_minutes'].unique()))
    uld_break = list(new_check['unique_id'].unique())
    #shipment_arrival_time_minutes_loop = list(new_check['Shipment_arrival_time_minutes'].unique())[0]
    #shipment_arrival_duation_minutes_loop = list(new_check['one_hour_duration'].unique())[0] #list(new_check['Shipment_duration_minutes'].unique())[0]
    handling_minutes = list(new_check['handling_m'].unique())[0]
    #print(handling_minutes)
    cap = list(new_check['NumberOfWorkstations'].unique())[0]
    for t in range(min_time, max_time-handling_minutes-1, handling_minutes):
        #print(t)
        uld_list1=[]
        for i in uld_break:
            if(t in range((min_time + (math.ceil((new_check[new_check.unique_id==i].iloc[0]['Shipment_arrival_time_minutes']-min_time)/df_merge1[df_merge1.BreakDownZoneName==j].iloc[0]['handling_m'])*df_merge1[df_merge1.BreakDownZoneName==j].iloc[0]['handling_m'])), (min_time + (math.ceil((new_check[new_check.unique_id==i].iloc[0]['Shipment_arrival_time_minutes']-min_time)/df_merge1[df_merge1.BreakDownZoneName==j].iloc[0]['handling_m'])*df_merge1[df_merge1.BreakDownZoneName==j].iloc[0]['handling_m']))+shipment_arrival_duation_minutes_loop, df_merge1[df_merge1.BreakDownZoneName==j].iloc[0]['handling_m'])):#new_check[new_check.ArrivalULDNumber==i].iloc[0]['Shipment_departure_time_minutes'])): 
                uld_list1.append(i)
                #print(t,uld_list1)
        if(len(uld_list1)!=0):
            model.addConstr(quicksum(x[a,j,t] for a in uld_list1) <= cap)

# %%
##########################################################################################################################################################################################
##########################################################################################################################################################################################

# %%
#BU Constraints

# %%
for k in filghts_list:
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.FlightNumberDeparture==k]['departure_date'].unique())
    for d in shipment_date_list:
        shipment_list = list(sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['shipment_ID'])
        ws_list = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Count'].unique()[0]
        shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_departure_time_minutes'].unique()[0]
    #print(shipment_list)
        for l in shipment_list:
        #print(int(i),str(j))
            if((len(shipment_list)!=0)):
                model.addConstr(quicksum(z[l,m,t] for m in range(1, ws_list+1) for t in range(shipment_departure_time_minutes_loop-60, shipment_departure_time_minutes_loop))==1)

# %%
for k in filghts_list:
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.FlightNumberDeparture==k]['departure_date'].unique())
    for d in shipment_date_list:
        shipment_list = list(sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['shipment_ID'])
        ws_list = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Count'].unique()[0]
        shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_departure_time_minutes'].unique()[0]
        bu_handling_time = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['handling_ULD_m'].unique()[0]
        #print(bu_handling_time.dtype)
    #print(shipment_list)
        for m in range(1, ws_list+1):
            for t in range(shipment_departure_time_minutes_loop-60, shipment_departure_time_minutes_loop-bu_handling_time):
                if((len(shipment_list)!=0)):
                    model.addConstr(400*q[k,m,t] - quicksum(sample_shipments_bu[sample_shipments_bu.shipment_ID==l].iloc[0]['TotalWeight']*z[l,m,t] for l in shipment_list) 
                                >= quicksum(sample_shipments_bu[sample_shipments_bu.shipment_ID==l].iloc[0]['TotalWeight']*z[l,m,tau] for l in shipment_list for tau in range(t+1,t+bu_handling_time)))

# %%
for k in filghts_list:
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.FlightNumberDeparture==k]['departure_date'].unique())
    for d in shipment_date_list:
        shipment_list = list(sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k)  & (sample_shipments_bu.departure_date==d)]['shipment_ID'])
        ws_list = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k)   & (sample_shipments_bu.departure_date==d)]['Count'].unique()[0]
        shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k)  & (sample_shipments_bu.departure_date==d)]['Shipment_departure_time_minutes'].unique()[0]
        bu_handling_time = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k)  & (sample_shipments_bu.departure_date==d)]['handling_ULD_m'].unique()[0]
        if((len(shipment_list)!=0)):
            model.addConstr(quicksum(q[k,m,t] for m in range(1, ws_list+1) for t in range(shipment_departure_time_minutes_loop-60, shipment_departure_time_minutes_loop)) <= (quicksum(sample_shipments_bu[sample_shipments_bu.shipment_ID==l].iloc[0]['TotalWeight']*z[l,m,t] for l in shipment_list for t in range(shipment_departure_time_minutes_loop-60,shipment_departure_time_minutes_loop) for m in range(1, ws_list+1))/400) + 1)

# %%
for k in filghts_list:
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.FlightNumberDeparture==k]['departure_date'].unique())
    for d in shipment_date_list:
        bu_zone_for_flight = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Name_x'].unique()[0]
        othe_flights_df = sample_shipments_bu[(sample_shipments_bu.Name_x==bu_zone_for_flight) & (sample_shipments_bu.departure_date==d)]
        ws_list = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Count'].unique()[0]
        shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_departure_time_minutes'].unique()[0]
        other_flights = list(othe_flights_df[(othe_flights_df['FlightNumberDeparture'].isin([k]) == False) & (othe_flights_df.departure_date==d)]['FlightNumberDeparture'].unique())
        bu_handling_time = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['handling_ULD_m'].unique()[0]
        #print(k, "----",filghts_list,"-------", other_flights) 
        #print(shipment_list)
        for m in range(1, ws_list+1):
        #print(int(i),str(j))
            for t in range(shipment_departure_time_minutes_loop-60, shipment_departure_time_minutes_loop - bu_handling_time):
                other_list  =[]
                for i in other_flights:
                    if(t in range((sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==i)].iloc[0]['Shipment_departure_time_minutes']-60),sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==i)].iloc[0]['Shipment_departure_time_minutes'])): 
                        other_list.append(i)
                #print(k, "----",other_list)
                if(len(other_list)!=0):
                    model.addConstr(1-q[k,m,t] >= quicksum(q[p,m,ta] for p in other_list for ta in range(t,min(t+bu_handling_time,(sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==p)].iloc[0]['Shipment_departure_time_minutes'])))))

# %%
for i in (list(set(uld_uniqueid_list) - set(two_drop_zones_ULD_Numbers))):
    BreakDownZoneName_list1 = list(df_merge1[df_merge1.unique_id==i]['BreakDownZoneName'])
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.unique_id==i]['departure_date'].unique())
    for d in shipment_date_list:
        shipment_list = list(sample_shipments_bu[(sample_shipments_bu.unique_id==i) & (sample_shipments_bu.departure_date==d)]['shipment_ID'])
        #print(shipment_list)
        for l in shipment_list:
            number_of_ws = sample_shipments_bu[(sample_shipments_bu.unique_id==i) & (sample_shipments_bu.shipment_ID==l)]['Count'].unique()[0]
            shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.unique_id==i) & (sample_shipments_bu.shipment_ID==l)]['Shipment_departure_time_minutes'].unique()[0]
            #shipment_arrival_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.unique_id==i) & (sample_shipments_bu.shipment_ID==l)]['Shipment_arrival_time_minutes'].unique()[0]
            new_check = df_merge1[(df_merge1.unique_id==i)]
            shipment_arrival_time_minutes_loop = list(new_check['Shipment_arrival_time_minutes'].unique())[0]
            if((len(shipment_list)!=0)):
                model.addConstr(quicksum(t*z[l,m,t] for m in range(1, ws_list+1) for t in range(shipment_departure_time_minutes_loop-60, shipment_departure_time_minutes_loop)) >=
                            quicksum((k + df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m'] + 
                                      df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['m'])*x[i,b,k] for b in BreakDownZoneName_list1 for k in range((min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((shipment_arrival_time_minutes_loop-min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))), (min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((shipment_arrival_time_minutes_loop-min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))) +shipment_arrival_duation_minutes_loop, df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m'])), name="Constraint 9")

# %%
for i in (two_drop_zones_ULD_Numbers):
    BreakDownZoneName_list1 = list(df_merge1[df_merge1.unique_id==i]['BreakDownZoneName'])
    bd_NRML_list = [k for k in BreakDownZoneName_list1 if 'NRML' in k]
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.unique_id==i]['departure_date'].unique())
    for d in shipment_date_list:
        shipment_list = list(sample_shipments_bu[(sample_shipments_bu.unique_id==i) & (sample_shipments_bu.departure_date==d)]['shipment_ID'])
        #print(shipment_list)
        for l in shipment_list:
            number_of_ws = sample_shipments_bu[(sample_shipments_bu.unique_id==i) & (sample_shipments_bu.shipment_ID==l)]['Count'].unique()[0]
            shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.unique_id==i) & (sample_shipments_bu.shipment_ID==l)]['Shipment_departure_time_minutes'].unique()[0]
            #shipment_arrival_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.unique_id==i) & (sample_shipments_bu.shipment_ID==l)]['Shipment_arrival_time_minutes'].unique()[0]
            new_check = df_merge1[(df_merge1.unique_id==i)]
            shipment_arrival_time_minutes_loop = list(new_check['Shipment_arrival_time_minutes'].unique())[0]
            if((len(shipment_list)!=0)):
                model.addConstr(quicksum(t*z[l,m,t] for m in range(1, ws_list+1) for t in range(shipment_departure_time_minutes_loop-60, shipment_departure_time_minutes_loop)) >=
                            quicksum((k + df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m'] + 
                                      df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['m'])*x[i,b,k] for b in bd_NRML_list for k in range((min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((shipment_arrival_time_minutes_loop-min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))), (min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((shipment_arrival_time_minutes_loop-min(list(df_merge1[df_merge1.BreakDownZoneName==b]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m']))) +shipment_arrival_duation_minutes_loop, df_merge1[df_merge1.BreakDownZoneName==b].iloc[0]['handling_m'])), name="Constraint Others")

# %%
s_min = model.addVar(vtype=GRB.INTEGER, name="s_min")

# %%
model.addConstr(s_min>=0)
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %%
for i in ArrivalULDNumber_list:
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.ArrivalULDNumber==i]['departure_date'].unique())
    for d in shipment_date_list:
        shipment_list = list(sample_shipments_bu[(sample_shipments_bu.ArrivalULDNumber==i) & (sample_shipments_bu.departure_date==d)]['shipment_ID'])
    #print(shipment_list)
        for l in shipment_list:
        #print(int(i),str(j))
            number_of_ws = sample_shipments_bu[(sample_shipments_bu.ArrivalULDNumber==i) & (sample_shipments_bu.shipment_ID==l)]['Count'].unique()[0]
            shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.ArrivalULDNumber==i) & (sample_shipments_bu.shipment_ID==l)]['Shipment_departure_time_minutes'].unique()[0]
            if((len(shipment_list)!=0)):
                model.addConstr(shipment_departure_time_minutes_loop-(quicksum(t*z[l,m,t] for m in range(1,number_of_ws+1) for t in range(shipment_departure_time_minutes_loop-60, shipment_departure_time_minutes_loop)))>=s_min)

# %%
obj = s_min
for i in ArrivalULDNumber_list:
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.ArrivalULDNumber==i]['departure_date'].unique())
    for d in shipment_date_list:
        shipment_list = list(sample_shipments_bu[(sample_shipments_bu.ArrivalULDNumber==i) & (sample_shipments_bu.departure_date==d)]['shipment_ID'])
    #print(shipment_list)
        for l in shipment_list:
        #print(int(i),str(j))
            number_of_ws = sample_shipments_bu[(sample_shipments_bu.ArrivalULDNumber==i) & (sample_shipments_bu.shipment_ID==l)]['Count'].unique()[0]
            shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.ArrivalULDNumber==i) & (sample_shipments_bu.shipment_ID==l)]['Shipment_departure_time_minutes'].unique()[0]
            if((len(shipment_list)!=0)):
                obj += (shipment_departure_time_minutes_loop-quicksum(t*z[l,m,t] for m in range(1,number_of_ws+1) for t in range(shipment_departure_time_minutes_loop-60, shipment_departure_time_minutes_loop)))

# %%
model.setObjective(obj, GRB.MAXIMIZE)
model.optimize()
# Out:
# Optimize a model with 22563 rows, 205839 columns and 3103474 nonzeros
# Variable types: 0 continuous, 205839 integer (205838 binary)
# Coefficient statistics:
#   Matrix range     [5e-04, 3e+07]
#   Objective range  [1e+00, 3e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+07]
# Presolve removed 3846 rows and 40509 columns (presolve time = 5s) ...
# Presolve removed 5221 rows and 79773 columns (presolve time = 10s) ...
# Presolve removed 5276 rows and 81653 columns (presolve time = 17s) ...
# Presolve removed 20452 rows and 196317 columns
# Presolve time: 18.15s
# Presolved: 2111 rows, 9522 columns, 41391 nonzeros
# Variable types: 0 continuous, 9522 integer (9521 binary)
# Found heuristic solution: objective 17311.000000
# Found heuristic solution: objective 28403.000000
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7125207e+10   3.496960e+05   0.000000e+00     19s
#     1241    3.8766012e+04   0.000000e+00   0.000000e+00     19s
#
# Root relaxation: objective 3.876601e+04, 1241 iterations, 0.06 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 38766.0124    0   64 28403.0000 38766.0124  36.5%     -   19s
# H    0     0                    36247.000000 38766.0124  6.95%     -   19s
# H    0     0                    38637.000000 38766.0124  0.33%     -   19s
#      0     0 38765.6159    0   85 38637.0000 38765.6159  0.33%     -   19s
#      0     0 38759.9768    0   81 38637.0000 38759.9768  0.32%     -   19s
#      0     0 38744.8409    0   92 38637.0000 38744.8409  0.28%     -   19s
#      0     0 38713.2652    0   86 38637.0000 38713.2652  0.20%     -   19s
#      0     0 38713.2638    0   89 38637.0000 38713.2638  0.20%     -   19s
#      0     0 38708.7646    0   75 38637.0000 38708.7646  0.19%     -   19s
# H    0     0                    38643.000000 38708.7646  0.17%     -   19s
#      0     0 38669.1191    0   88 38643.0000 38669.1191  0.07%     -   19s
#      0     0 38669.1113    0   87 38643.0000 38669.1113  0.07%     -   20s
#      0     0 38668.3782    0   81 38643.0000 38668.3782  0.07%     -   20s
#      0     0 38668.3782    0   47 38643.0000 38668.3782  0.07%     -   20s
#      0     0 38668.3782    0   76 38643.0000 38668.3782  0.07%     -   20s
#      0     0 38668.3782    0   76 38643.0000 38668.3782  0.07%     -   20s
#      0     0 38659.6282    0   71 38643.0000 38659.6282  0.04%     -   20s
#      0     0 38659.6282    0   76 38643.0000 38659.6282  0.04%     -   20s
#      0     0 38659.6282    0   73 38643.0000 38659.6282  0.04%     -   20s
#      0     0 38659.6128    0   80 38643.0000 38659.6128  0.04%     -   20s
#      0     0 38659.6128    0   67 38643.0000 38659.6128  0.04%     -   20s
# H    0     0                    38646.000000 38659.6128  0.04%     -   20s
#      0     2 38659.6128    0   65 38646.0000 38659.6128  0.04%     -   20s
# H  304   139                    38647.319010 38650.8706  0.01%  10.3   21s
#
# Cutting planes:
#   Gomory: 17
#   Cover: 43
#   Clique: 18
#   MIR: 12
#   StrongCG: 8
#   GUB cover: 2
#
# Explored 330 nodes (6243 simplex iterations) in 21.83 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 8: 38647.3 38646 38643 ... 17311
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.864731900787e+04, best bound 3.865000000000e+04, gap 0.0069%

# %%
print(s_min)
# Out:
# <gurobi.Var s_min (value 1.0)>

# %%
sample_shipments_bu.shape
# Out:
# (43, 56)

# %%
#import datetime
print(dt.datetime.now())
# Out:
# 2019-07-01 15:42:25.673393

# %%
model.write('Full_Model_smin.lp')
# Out:
# Warning: constraint name "Constraint 9" has a space

# %%
for i in uld_uniqueid_list:
    BreakDownZoneName_list1 = list(df_merge1[df_merge1.unique_id==i]['BreakDownZoneName'])
    #print(i, "in", BreakDownZoneName_list1)
    for j in BreakDownZoneName_list1:
        #print(int(i),str(j))
        new_check = df_merge1[(df_merge1.unique_id==i) & (df_merge1.BreakDownZoneName==j)]
        shipment_arrival_time_minutes_loop = list(new_check['Shipment_arrival_time_minutes'].unique())[0]
        shipment_arrival_duation_minutes_loop = list(new_check['one_hour_duration'].unique())[0] #list(new_check['Shipment_duration_minutes'].unique())[0]
        for k in range((min(list(df_merge1[df_merge1.BreakDownZoneName==j]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((shipment_arrival_time_minutes_loop-min(list(df_merge1[df_merge1.BreakDownZoneName==j]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==j].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==j].iloc[0]['handling_m']))), (min(list(df_merge1[df_merge1.BreakDownZoneName==j]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((shipment_arrival_time_minutes_loop-min(list(df_merge1[df_merge1.BreakDownZoneName==j]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==j].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==j].iloc[0]['handling_m']))) +shipment_arrival_duation_minutes_loop, df_merge1[df_merge1.BreakDownZoneName==j].iloc[0]['handling_m']):
            if x[i,j,k].x > 0.5:
                print("ULD", i, "assigned to BD", j, "at", k)
                #print(k)
            #if(i == '51228_25671360'):
                #print(x)
# Out:
# ULD 21231_25671250 assigned to BD BD NRML-4 at 25671312
# ULD 21231_25671250 assigned to BD BD NML-3 at 25671280
# ULD 24321_25671250 assigned to BD BD NRML-1 at 25671270
# ULD 42309_25671550 assigned to BD BD NRML-1 at 25671570
# ULD 49809_25673105 assigned to BD BD NRML-4 at 25673119
# ULD 44509_25671785 assigned to BD BD NRML-1 at 25671790
# ULD 44509_25673225 assigned to BD BD NRML-1 at 25673230
# ULD 34521_25671730 assigned to BD BD NRML-1 at 25671750
# ULD 34576_25671730 assigned to BD BD NRML-1 at 25671750
# ULD 34849_25673345 assigned to BD BD NRML-1 at 25673350
# ULD 53252_25671910 assigned to BD BD NRML-4 at 25671923
# ULD 92841_25672010 assigned to BD BD NRML-4 at 25672027
# ULD 92852_25680385 assigned to BD BD NRML-1 at 25680390
# ULD 92852_25671325 assigned to BD BD NRML-4 at 25671364
# ULD 92852_25671325 assigned to BD BD NML-3 at 25671340
# ULD 92854_25674170 assigned to BD BD NRML-4 at 25674185
# ULD 92854_25672730 assigned to BD B BD NRML-1 at 25672750
# ULD 92862_25671510 assigned to BD BD NRML-1 at 25671530
# ULD 92863_25672040 assigned to BD BD NRML-1 at 25672050
# ULD 92874_25673595 assigned to BD BD NRML-1 at 25673610
# ULD 55210_25671480 assigned to BD BD NRML-1 at 25671490
# ULD 55233_25671900 assigned to BD BD NRML-1 at 25671910
# ULD 55234_25671960 assigned to BD BD NRML-1 at 25671970
# ULD 55244_25672140 assigned to BD BD NRML-4 at 25672183
# ULD 55244_25672140 assigned to BD BD NML-3 at 25672160
# ULD 55242_25674680 assigned to BD BD NRML-1 at 25674690
# ULD 55256_25674295 assigned to BD BD NRML-1 at 25674310
# ULD 12199_25674165 assigned to BD BD NRML-1 at 25674170
# ULD 55267_25672735 assigned to BD B BD NRML-1 at 25672750
# ULD 55267_25674175 assigned to BD BD NRML-1 at 25674190
# ULD 51207_25670350 assigned to BD BD NRML-4 at 25670363
# ULD 51217_25673010 assigned to BD BD NRML-4 at 25673028
# ULD 51217_25673700 assigned to BD BD NRML-1 at 25673710
# ULD 51216_25671740 assigned to BD BD NRML-1 at 25671750
# ULD 51219_25672035 assigned to BD BD NRML-1 at 25672050
# ULD 51227_25672240 assigned to BD BD NRML-1 at 25672250
# ULD 51227_25675120 assigned to BD BD NRML-1 at 25675130
# ULD 51228_25671360 assigned to BD BD NRML-4 at 25671403
# ULD 51228_25671360 assigned to BD BD NML-3 at 25671380
# ULD 51229_25674220 assigned to BD BD NRML-1 at 25674230
# ULD 51230_25671470 assigned to BD BD NRML-1 at 25671510
# ULD 51230_25671470 assigned to BD BD NML-2 at 25671496
# ULD 59235_25673080 assigned to BD BD NRML-1 at 25673090
# ULD 59247_25673640 assigned to BD BD NRML-1 at 25673690
# ULD 59247_25673640 assigned to BD BD NML-2 at 25673667
# ULD 59247_25672200 assigned to BD BD NRML-1 at 25672210
# ULD 59248_25671295 assigned to BD BD NRML-1 at 25671310
# ULD 59259_25671330 assigned to BD BD NRML-1 at 25671350
# ULD 59268_25672210 assigned to BD BD NRML-1 at 25672230
# ULD 59271_25671300 assigned to BD BD NRML-1 at 25671350
# ULD 59271_25671300 assigned to BD BD NML-2 at 25671327
# ULD 43330_25673080 assigned to BD BD NRML-1 at 25673090
# ULD 59290_25672955 assigned to BD BD NRML-4 at 25673002
# ULD 59290_25672955 assigned to BD BD NML-3 at 25672980
# ULD 44913_25672695 assigned to BD BD NRML-1 at 25672710
# ULD 44914_25673110 assigned to BD BD NRML-4 at 25673171
# ULD 44914_25673110 assigned to BD BD NML-1 at 25673147
# ULD 44915_25672785 assigned to BD BD NRML-4 at 25672820
# ULD 44915_25672785 assigned to BD BD NML-3 at 25672800
# ULD 44916_25673085 assigned to BD BD NRML-1 at 25673090
# ULD 54552_25673030 assigned to BD BD NRML-1 at 25673050
# ULD 44924_25673055 assigned to BD BD NRML-1 at 25673070
# ULD 44925_25672940 assigned to BD BD NRML-1 at 25672950
# ULD 44926_25671855 assigned to BD BD NRML-1 at 25671870
# ULD 44927_25673150 assigned to BD BD NRML-4 at 25673210
# ULD 44927_25673150 assigned to BD BD NML-1 at 25673186
# ULD 46300_25672740 assigned to BD BD NRML-1 at 25672750
# ULD 44935_25674820 assigned to BD BD NRML-1 at 25674830
# ULD 44947_25672925 assigned to BD BD NRML-1 at 25672930
# ULD 44948_25671925 assigned to BD BD NRML-1 at 25671930
# ULD 44948_25673365 assigned to BD BD NRML-1 at 25673370
# ULD 44949_25673140 assigned to BD BD NRML-1 at 25673150
# ULD 44957_25672770 assigned to BD BD NRML-1 at 25672810
# ULD 44957_25672770 assigned to BD BD NML-2 at 25672796
# ULD 44958_25672860 assigned to BD BD NRML-1 at 25672910
# ULD 44958_25672860 assigned to BD BD NML-3 at 25672880
# ULD 44959_25673340 assigned to BD BD NRML-1 at 25673350
# ULD 49808_25671320 assigned to BD BD NRML-1 at 25671330
# ULD 49811_25672390 assigned to BD BD NRML-4 at 25672404
# ULD 49820_25672855 assigned to BD BD NRML-1 at 25672870
# ULD 49822_25673150 assigned to BD BD NRML-4 at 25673210
# ULD 49822_25673150 assigned to BD BD NML-2 at 25673186
# ULD 49831_25673655 assigned to BD BD NRML-1 at 25673670
# ULD 49832_25673110 assigned to BD BD NRML-1 at 25673130
# ULD 49833_25672620 assigned to BD BD NRML-1 at 25672630
# ULD 49841_25674465 assigned to BD BD NRML-1 at 25674470
# ULD 32109_25673205 assigned to BD BD NRML-1 at 25673210
# ULD 80114_25680255 assigned to BD BD NRML-4 at 25680269
# ULD 80136_25671540 assigned to BD BD NRML-1 at 25671550
# ULD 80137_25672200 assigned to BD BD NRML-1 at 25672210
# ULD 80146_25671865 assigned to BD BD NRML-1 at 25671870
# ULD 80157_25672800 assigned to BD BD NRML-1 at 25672810
# ULD 80158_25671650 assigned to BD BD NRML-1 at 25671670
# ULD 80159_25672200 assigned to BD BD NRML-1 at 25672210
# ULD 80168_25671750 assigned to BD BD NRML-4 at 25671767
# ULD 80169_25672890 assigned to BD B BD NRML-1 at 25672918
# ULD 80182_25672060 assigned to BD BD NRML-1 at 25672070
# ULD 80190_25673055 assigned to BD BD NRML-1 at 25673070
# ULD 80192_25671740 assigned to BD BD NRML-1 at 25671750
# ULD 80224_25671865 assigned to BD BD NRML-1 at 25671870
# ULD 80225_25673280 assigned to BD BD NRML-1 at 25673290
# ULD 80234_25676310 assigned to BD BD NRML-1 at 25676330
# ULD 80235_25672890 assigned to BD BD NRML-1 at 25672910
# ULD 80236_25672895 assigned to BD BD NRML-1 at 25672910
# ULD 80245_25671830 assigned to BD BD NRML-4 at 25671845
# ULD 80247_25672645 assigned to BD BD NRML-1 at 25672650
# ULD 80248_25673690 assigned to BD BD NRML-4 at 25673704
# ULD 80248_25673280 assigned to BD BD NRML-1 at 25673290
# ULD 80258_25673865 assigned to BD BD NRML-1 at 25673870
# ULD 80280_25675800 assigned to BD BD NRML-1 at 25675810
# ULD 80314_25672230 assigned to BD BD NRML-4 at 25672248
# ULD 23127_25671250 assigned to BD BD NRML-4 at 25671312
# ULD 23127_25671250 assigned to BD BD NML-3 at 25671280
# ULD 33565_25672775 assigned to BD BD NRML-1 at 25672790
# ULD 42313_25672985 assigned to BD BD NRML-4 at 25673028
# ULD 42313_25672985 assigned to BD BD NML-3 at 25673000
# ULD 42371_25673045 assigned to BD BD NRML-1 at 25673050
# ULD 42371_25671605 assigned to BD BD NRML-1 at 25671610
# ULD 34842_25673285 assigned to BD BD NRML-1 at 25673290
# ULD 53456_25671910 assigned to BD BD NRML-4 at 25671923
# ULD 53409_25671970 assigned to BD BD NRML-4 at 25671988
# ULD 76421_25672030 assigned to BD BD NRML-4 at 25672092
# ULD 76421_25672030 assigned to BD BD NML-3 at 25672060
# ULD 76631_25672090 assigned to BD BD NRML-1 at 25672090
# ULD 76609_25673545 assigned to BD BD NRML-1 at 25673550
# ULD 76932_25674160 assigned to BD BD NRML-1 at 25674170
# ULD 92812_25673345 assigned to BD BD NRML-1 at 25673350
# ULD 92812_25671905 assigned to BD BD NRML-1 at 25671910
# ULD 92859_25671385 assigned to BD BD NRML-1 at 25671390
# ULD 92866_25673510 assigned to BD BD NRML-1 at 25673530
# ULD 92868_25674130 assigned to BD BD NRML-4 at 25674146
# ULD 92868_25672690 assigned to BD BD NRML-4 at 25672742
# ULD 92868_25672690 assigned to BD BD NML-1 at 25672718
# ULD 92869_25672750 assigned to BD BD NRML-4 at 25672768
# ULD 92869_25674190 assigned to BD BD NRML-1 at 25674210
# ULD 92870_25671240 assigned to BD BD NRML-1 at 25671250
# ULD 42424_25671240 assigned to BD BD NRML-1 at 25671250
# ULD 92871_25671360 assigned to BD BD NRML-1 at 25671370
# ULD 55215_25671540 assigned to BD BD NRML-4 at 25671585
# ULD 55215_25671540 assigned to BD BD NML-3 at 25671560
# ULD 55219_25671600 assigned to BD BD NRML-1 at 25671610
# ULD 55224_25673170 assigned to BD BD NRML-4 at 25673184
# ULD 55224_25671730 assigned to BD BD NRML-1 at 25671750
# ULD 55226_25671720 assigned to BD BD NRML-1 at 25671730
# ULD 55228_25673230 assigned to BD BD NRML-1 at 25673250
# ULD 55230_25671840 assigned to BD BD NRML-1 at 25671850
# ULD 55235_25672020 assigned to BD BD NRML-1 at 25672030
# ULD 55239_25672080 assigned to BD BD NRML-1 at 25672090
# ULD 55251_25673535 assigned to BD BD NRML-4 at 25673548
# ULD 55257_25673120 assigned to BD BD NRML-1 at 25673130
# ULD 55258_25676300 assigned to BD BD NRML-1 at 25676310
# ULD 55259_25671520 assigned to BD BD NRML-1 at 25671530
# ULD 96654_25672900 assigned to BD B BD NRML-1 at 25672918
# ULD 74544_25673460 assigned to BD BD NRML-1 at 25673470
# ULD 11131_25672715 assigned to BD BD NRML-4 at 25672729
# ULD 55260_25671240 assigned to BD BD NRML-1 at 25671250
# ULD 55261_25672210 assigned to BD BD NRML-1 at 25672230
# ULD 55263_25679125 assigned to BD BD NRML-1 at 25679130
# ULD 55268_25671385 assigned to BD BD NRML-1 at 25671390
# ULD 55269_25673095 assigned to BD BD NRML-1 at 25673110
# ULD 51200_25671655 assigned to BD BD NRML-1 at 25671670
# ULD 51201_25671775 assigned to BD BD NRML-1 at 25671790
# ULD 51202_25671895 assigned to BD BD NRML-1 at 25671910
# ULD 51203_25672135 assigned to BD BD NRML-4 at 25672183
# ULD 51203_25672135 assigned to BD BD NML-3 at 25672160
# ULD 51209_25673055 assigned to BD BD NRML-1 at 25673070
# ULD 51209_25674495 assigned to BD BD NRML-1 at 25674510
# ULD 51210_25671890 assigned to BD BD NRML-1 at 25671910
# ULD 51212_25671720 assigned to BD BD NRML-1 at 25671730
# ULD 51213_25672000 assigned to BD BD NRML-4 at 25672040
# ULD 51213_25672000 assigned to BD BD NML-3 at 25672020
# ULD 51214_25673155 assigned to BD BD NRML-1 at 25673170
# ULD 51215_25674260 assigned to BD BD NRML-1 at 25674270
# ULD 51221_25673350 assigned to BD BD NRML-4 at 25673366
# ULD 51223_25672075 assigned to BD BD NRML-1 at 25672090
# ULD 51233_25674320 assigned to BD BD NRML-1 at 25674330
# ULD 51235_25671570 assigned to BD BD NRML-4 at 25671585
# ULD 59239_25671760 assigned to BD BD NRML-4 at 25671806
# ULD 59239_25671760 assigned to BD BD NML-3 at 25671780
# ULD 59243_25671650 assigned to BD BD NRML-4 at 25671663
# ULD 59243_25673090 assigned to BD BD NRML-4 at 25673106
# ULD 59243_25673345 assigned to BD BD NRML-1 at 25673390
# ULD 59243_25673345 assigned to BD BD NML-3 at 25673360
# ULD 59245_25672025 assigned to BD BD NRML-1 at 25672030
# ULD 59254_25671855 assigned to BD BD NRML-1 at 25671870
# ULD 59255_25671980 assigned to BD BD NRML-1 at 25671990
# ULD 59263_25672825 assigned to BD BD NRML-1 at 25672830
# ULD 59264_25674540 assigned to BD BD NRML-1 at 25674550
# ULD 59265_25671800 assigned to BD BD NRML-1 at 25671810
# ULD 59284_25673080 assigned to BD BD NRML-1 at 25673090
# ULD 59285_25672610 assigned to BD B BD NRML-1 at 25672654
# ULD 59285_25672610 assigned to BD BD NML-1 at 25672640
# ULD 59287_25672710 assigned to BD BD NRML-1 at 25672730
# ULD 59288_25672015 assigned to BD BD NRML-4 at 25672027
# ULD 44909_25674600 assigned to BD BD NRML-1 at 25674610
# ULD 44911_25671385 assigned to BD BD NRML-1 at 25671390
# ULD 44912_25673030 assigned to BD BD NRML-1 at 25673050
# ULD 44917_25672775 assigned to BD BD NRML-1 at 25672790
# ULD 44918_25673115 assigned to BD BD NRML-1 at 25673170
# ULD 44918_25673115 assigned to BD BD NML-3 at 25673140
# ULD 44919_25672690 assigned to BD BD NRML-4 at 25672703
# ULD 44921_25673195 assigned to BD BD NRML-1 at 25673210
# ULD 44923_25672915 assigned to BD BD NRML-1 at 25672930
# ULD 44928_25672740 assigned to BD BD NRML-1 at 25672750
# ULD 44929_25673330 assigned to BD BD NRML-1 at 25673350
# ULD 44932_25673240 assigned to BD BD NRML-1 at 25673250
# ULD 44932_25671800 assigned to BD BD NRML-1 at 25671810
# ULD 44934_25672740 assigned to BD BD NRML-1 at 25672750
# ULD 44941_25671400 assigned to BD BD NRML-1 at 25671410
# ULD 44942_25673260 assigned to BD BD NRML-1 at 25673270
# ULD 44944_25671535 assigned to BD BD NRML-1 at 25671550
# ULD 44944_25672975 assigned to BD BD NRML-1 at 25672990
# ULD 44945_25672775 assigned to BD BD NRML-1 at 25672790
# ULD 44951_25672555 assigned to BD BD NRML-1 at 25672570
# ULD 44953_25672555 assigned to BD BD NRML-1 at 25672570
# ULD 44953_25673995 assigned to BD BD NRML-1 at 25674010
# ULD 54322_25673175 assigned to BD BD NRML-1 at 25673190
# ULD 54323_25673255 assigned to BD BD NRML-1 at 25673270
# ULD 54324_25672620 assigned to BD BD NRML-1 at 25672630
# ULD 49802_25673485 assigned to BD BD NRML-1 at 25673490
# ULD 49803_25673675 assigned to BD BD NRML-1 at 25673690
# ULD 49804_25673610 assigned to BD BD NRML-4 at 25673626
# ULD 49806_25672020 assigned to BD BD NRML-1 at 25672030
# ULD 49813_25673700 assigned to BD BD NRML-1 at 25673710
# ULD 49813_25675140 assigned to BD BD NRML-1 at 25675150
# ULD 49815_25672940 assigned to BD BD NRML-1 at 25672950
# ULD 49815_25674380 assigned to BD BD NRML-1 at 25674430
# ULD 49815_25674380 assigned to BD BD NML-3 at 25674400
# ULD 49817_25672770 assigned to BD BD NRML-1 at 25672810
# ULD 49817_25672770 assigned to BD BD NML-2 at 25672796
# ULD 49817_25674210 assigned to BD BD NRML-4 at 25674224
# ULD 49823_25672595 assigned to BD BD NRML-1 at 25672610
# ULD 49824_25674200 assigned to BD BD NRML-1 at 25674250
# ULD 49824_25674200 assigned to BD BD NML-2 at 25674226
# ULD 49826_25673785 assigned to BD BD NRML-1 at 25673790
# ULD 49827_25673690 assigned to BD BD NRML-4 at 25673704
# ULD 49828_25671275 assigned to BD BD NRML-1 at 25671290
# ULD 49835_25673235 assigned to BD B BD NRML-1 at 25673278
# ULD 49835_25673235 assigned to BD BD NML-2 at 25673264
# ULD 49835_25674675 assigned to BD BD NRML-1 at 25674690
# ULD 49836_25672640 assigned to BD BD NRML-1 at 25672650
# ULD 49837_25672855 assigned to BD BD NRML-1 at 25672870
# ULD 49839_25674340 assigned to BD BD NRML-1 at 25674350
# ULD 49846_25672600 assigned to BD BD NRML-1 at 25672610
# ULD 80117_25675230 assigned to BD BD NRML-1 at 25675250
# ULD 80118_25673045 assigned to BD BD NRML-1 at 25673050
# ULD 80119_25672275 assigned to BD BD NRML-1 at 25672290
# ULD 80121_25673055 assigned to BD BD NRML-1 at 25673070
# ULD 80129_25672780 assigned to BD BD NRML-1 at 25672790
# ULD 80131_25671700 assigned to BD BD NRML-1 at 25671710
# ULD 80132_25671365 assigned to BD BD NRML-1 at 25671370
# ULD 80133_25672150 assigned to BD BD NRML-1 at 25672170
# ULD 80134_25671425 assigned to BD BD NRML-1 at 25671430
# ULD 80139_25673160 assigned to BD BD NRML-1 at 25673170
# ULD 80141_25674420 assigned to BD BD NRML-1 at 25674430
# ULD 80142_25672765 assigned to BD BD NRML-1 at 25672790
# ULD 80143_25672185 assigned to BD BD NRML-1 at 25672190
# ULD 80144_25671380 assigned to BD BD NRML-1 at 25671390
# ULD 80151_25671760 assigned to BD BD NRML-1 at 25671770
# ULD 80152_25672060 assigned to BD BD NRML-1 at 25672070
# ULD 80155_25672865 assigned to BD B BD NRML-1 at 25672918
# ULD 80155_25672865 assigned to BD BD NML-3 at 25672880
# ULD 80156_25671355 assigned to BD BD NRML-1 at 25671370
# ULD 80161_25671340 assigned to BD BD NRML-1 at 25671350
# ULD 80162_25672960 assigned to BD BD NRML-1 at 25672970
# ULD 80164_25671860 assigned to BD BD NRML-1 at 25671870
# ULD 80167_25672975 assigned to BD BD NRML-1 at 25672990
# ULD 80173_25673040 assigned to BD BD NRML-1 at 25673050
# ULD 80175_25672185 assigned to BD BD NRML-1 at 25672190
# ULD 80176_25672900 assigned to BD B BD NRML-1 at 25672918
# ULD 80177_25671650 assigned to BD BD NRML-4 at 25671663
# ULD 80178_25672190 assigned to BD BD NRML-1 at 25672210
# ULD 80183_25671315 assigned to BD BD NRML-1 at 25671330
# ULD 80185_25676090 assigned to BD BD NRML-4 at 25676109
# ULD 80194_25671915 assigned to BD BD NRML-1 at 25671930
# ULD 80196_25673055 assigned to BD BD NRML-1 at 25673070
# ULD 80197_25671650 assigned to BD BD NRML-4 at 25671663
# ULD 80199_25674595 assigned to BD BD NRML-1 at 25674610
# ULD 80220_25673650 assigned to BD BD NRML-4 at 25673665
# ULD 80220_25672210 assigned to BD BD NRML-1 at 25672230
# ULD 80227_25673100 assigned to BD BD NRML-1 at 25673110
# ULD 80228_25673020 assigned to BD BD NRML-1 at 25673030
# ULD 80230_25673690 assigned to BD BD NRML-4 at 25673704
# ULD 80232_25673220 assigned to BD BD NRML-4 at 25673262
# ULD 80232_25673220 assigned to BD BD NML-3 at 25673240
# ULD 80233_25672900 assigned to BD B BD NRML-1 at 25672918
# ULD 80241_25673720 assigned to BD BD NRML-1 at 25673730
# ULD 80241_25674110 assigned to BD BD NRML-1 at 25674130
# ULD 80243_25672335 assigned to BD BD NRML-1 at 25672350
# ULD 80249_25676930 assigned to BD BD NRML-1 at 25676950
# ULD 80251_25673765 assigned to BD BD NRML-4 at 25673808
# ULD 80251_25673765 assigned to BD BD NML-3 at 25673780
# ULD 80253_25671660 assigned to BD BD NRML-4 at 25671702
# ULD 80253_25671660 assigned to BD BD NML-3 at 25671680
# ULD 80255_25676745 assigned to BD BD NRML-1 at 25676750
# ULD 80262_25672590 assigned to BD BD NRML-1 at 25672610
# ULD 80265_25675320 assigned to BD BD NRML-1 at 25675330
# ULD 80271_25671210 assigned to BD BD NRML-1 at 25671230
# ULD 80274_25674480 assigned to BD BD NRML-1 at 25674490
# ULD 80277_25675740 assigned to BD BD NRML-1 at 25675750
# ULD 80283_25679820 assigned to BD BD NRML-1 at 25679830
# ULD 80286_25672470 assigned to BD BD NRML-1 at 25672490
# ULD 80295_25673695 assigned to BD BD NRML-1 at 25673710
# ULD 80304_25674310 assigned to BD BD NRML-4 at 25674328
# ULD 80306_25674135 assigned to BD BD NRML-1 at 25674150
# ULD 80308_25671320 assigned to BD BD NRML-1 at 25671330
# ULD 80310_25672740 assigned to BD B BD NRML-1 at 25672774
# ULD 80316_25672620 assigned to BD BD NRML-1 at 25672630
# ULD 76901_25672765 assigned to BD BD NML-3 at 25672780
# ULD 92832_25671560 assigned to BD BD NML-3 at 25671580
# ULD 55237_25670820 assigned to BD BD NML-3 at 25670840
# ULD 51225_25672120 assigned to BD BD NML-3 at 25672140
# ULD 59252_25671665 assigned to BD BD NML-3 at 25671680
# ULD 59257_25672055 assigned to BD BD NML-3 at 25672080
# ULD 59281_25674500 assigned to BD BD NML-3 at 25674520
# ULD 59286_25671765 assigned to BD BD NML-3 at 25671780
# ULD 59286_25673205 assigned to BD BD NML-3 at 25673220
# ULD 49807_25673265 assigned to BD BD NML-3 at 25673280
# ULD 80179_25671805 assigned to BD BD NML-3 at 25671820
# ULD 80226_25672095 assigned to BD BD NML-3 at 25672120
# ULD 80249_25672610 assigned to BD BD NML-1 at 25672653

# %%
# visualize the optimal assignment
for i in uld_uniqueid_list:
    BreakDownZoneName_list1 = list(df_merge1[df_merge1.unique_id==i]['BreakDownZoneName'])
    for j in BreakDownZoneName_list1:
        #print(int(i),str(j))
        new_check = df_merge1[(df_merge1.unique_id==i) & (df_merge1.BreakDownZoneName==j)]
        shipment_arrival_time_minutes_loop = list(new_check['Shipment_arrival_time_minutes'].unique())[0]
        shipment_arrival_duation_minutes_loop = list(new_check['one_hour_duration'].unique())[0] #list(new_check['Shipment_duration_minutes'].unique())[0]
        for k in range((min(list(df_merge1[df_merge1.BreakDownZoneName==j]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((shipment_arrival_time_minutes_loop-min(list(df_merge1[df_merge1.BreakDownZoneName==j]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==j].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==j].iloc[0]['handling_m']))), (min(list(df_merge1[df_merge1.BreakDownZoneName==j]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((shipment_arrival_time_minutes_loop-min(list(df_merge1[df_merge1.BreakDownZoneName==j]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==j].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==j].iloc[0]['handling_m']))) +shipment_arrival_duation_minutes_loop, df_merge1[df_merge1.BreakDownZoneName==j].iloc[0]['handling_m']):
            if x[i,j,k].x > 0.5:
                #print(k)
                #print("DZ", i, "assigned to BD", j, "at", (shipment_arrival_time_minutes_loop+k))
                plt.plot(k, j, "o")
                #plt.annotate(i, (k,j))
# for j in range(m):    
#     plt.plot(1, j, "o")
# for i in range(n):
#     for j in range(m):
#         if x[i,j].x > 0.5:
#             plt.plot([0,1], [i,j], "k")# todo
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
for i in ArrivalULDNumber_list:
    shipment_list = list(sample_shipments_bu[sample_shipments_bu.ArrivalULDNumber==i]['shipment_ID'])
    #print(shipment_list)
    for l in shipment_list:
        #print(int(i),str(j))
        number_of_ws = sample_shipments_bu[(sample_shipments_bu.ArrivalULDNumber==i) & (sample_shipments_bu.shipment_ID==l)]['Count'].unique()[0]
        shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.ArrivalULDNumber==i) & (sample_shipments_bu.shipment_ID==l)]['Shipment_departure_time_minutes'].unique()[0]
        for m in range(1,number_of_ws+1):
            for t in range(shipment_departure_time_minutes_loop-60, shipment_departure_time_minutes_loop):
                if z[l,m,t].x > 0.5:
                    print("Shipment", l, "assigned to WS", m, "at", t)
# Out:
# Shipment 1 assigned to WS 3 at 25673872
# Shipment 7 assigned to WS 3 at 25677252
# Shipment 21 assigned to WS 1 at 25673412
# Shipment 30 assigned to WS 3 at 25677499
# Shipment 36 assigned to WS 1 at 25673505
# Shipment 37 assigned to WS 1 at 25673505
# Shipment 38 assigned to WS 1 at 25673505
# Shipment 48 assigned to WS 2 at 25675414
# Shipment 49 assigned to WS 2 at 25675414
# Shipment 50 assigned to WS 2 at 25675414
# Shipment 66 assigned to WS 3 at 25674397
# Shipment 74 assigned to WS 1 at 25673537
# Shipment 75 assigned to WS 1 at 25673537
# Shipment 82 assigned to WS 1 at 25676163
# Shipment 85 assigned to WS 2 at 25676983
# Shipment 89 assigned to WS 3 at 25674669
# Shipment 90 assigned to WS 3 at 25674669
# Shipment 91 assigned to WS 3 at 25674669
# Shipment 92 assigned to WS 3 at 25674669
# Shipment 93 assigned to WS 3 at 25674669
# Shipment 105 assigned to WS 3 at 25677353
# Shipment 106 assigned to WS 1 at 25677353
# Shipment 121 assigned to WS 1 at 25673265
# Shipment 2 assigned to WS 3 at 25673872
# Shipment 77 assigned to WS 1 at 25673537
# Shipment 109 assigned to WS 3 at 25677353
# Shipment 110 assigned to WS 2 at 25677353
# Shipment 3 assigned to WS 3 at 25673872
# Shipment 541 assigned to WS 3 at 25675677
# Shipment 4 assigned to WS 3 at 25673872
# Shipment 5 assigned to WS 3 at 25673872
# Shipment 6 assigned to WS 3 at 25673872
# Shipment 8 assigned to WS 3 at 25677252
# Shipment 454 assigned to WS 2 at 25673955
# Shipment 9 assigned to WS 2 at 25677252
# Shipment 24 assigned to WS 1 at 25673412
# Shipment 112 assigned to WS 1 at 25677353
# Shipment 243 assigned to WS 3 at 25681135
# Shipment 486 assigned to WS 2 at 25673295
# Shipment 10 assigned to WS 3 at 25677252
# Shipment 11 assigned to WS 3 at 25677252
# Shipment 12 assigned to WS 3 at 25677252
# Shipment 13 assigned to WS 3 at 25677252
# Shipment 95 assigned to WS 3 at 25674669
# Shipment 262 assigned to WS 2 at 25672436
# Shipment 263 assigned to WS 3 at 25672436
# Shipment 264 assigned to WS 3 at 25672436
# Shipment 625 assigned to WS 3 at 25672503
# Shipment 14 assigned to WS 2 at 25677252
# Shipment 15 assigned to WS 1 at 25677252
# Shipment 16 assigned to WS 2 at 25677252
# Shipment 17 assigned to WS 3 at 25677252
# Shipment 18 assigned to WS 2 at 25677252
# Shipment 19 assigned to WS 1 at 25677252
# Shipment 20 assigned to WS 2 at 25677252
# Shipment 22 assigned to WS 1 at 25673412
# Shipment 218 assigned to WS 2 at 25672436
# Shipment 219 assigned to WS 1 at 25672436
# Shipment 220 assigned to WS 1 at 25672436
# Shipment 221 assigned to WS 2 at 25672436
# Shipment 222 assigned to WS 1 at 25672436
# Shipment 223 assigned to WS 1 at 25672436
# Shipment 419 assigned to WS 3 at 25675661
# Shipment 427 assigned to WS 2 at 25674846
# Shipment 428 assigned to WS 3 at 25674265
# Shipment 438 assigned to WS 3 at 25673942
# Shipment 23 assigned to WS 1 at 25673412
# Shipment 31 assigned to WS 3 at 25677499
# Shipment 225 assigned to WS 1 at 25672436
# Shipment 226 assigned to WS 1 at 25672436
# Shipment 227 assigned to WS 1 at 25672436
# Shipment 228 assigned to WS 1 at 25672436
# Shipment 229 assigned to WS 1 at 25672436
# Shipment 230 assigned to WS 3 at 25672436
# Shipment 231 assigned to WS 1 at 25672436
# Shipment 232 assigned to WS 1 at 25672436
# Shipment 233 assigned to WS 1 at 25672436
# Shipment 440 assigned to WS 3 at 25674236
# Shipment 444 assigned to WS 2 at 25673246
# Shipment 446 assigned to WS 3 at 25674806
# Shipment 452 assigned to WS 2 at 25673955
# Shipment 25 assigned to WS 1 at 25673412
# Shipment 26 assigned to WS 1 at 25673412
# Shipment 27 assigned to WS 1 at 25673412
# Shipment 28 assigned to WS 1 at 25673412
# Shipment 29 assigned to WS 1 at 25673412
# Shipment 32 assigned to WS 3 at 25677499
# Shipment 56 assigned to WS 2 at 25675414
# Shipment 286 assigned to WS 3 at 25672436
# Shipment 287 assigned to WS 1 at 25672436
# Shipment 632 assigned to WS 3 at 25673540
# Shipment 643 assigned to WS 2 at 25674481
# Shipment 645 assigned to WS 2 at 25680782
# Shipment 647 assigned to WS 1 at 25672504
# Shipment 648 assigned to WS 1 at 25672504
# Shipment 33 assigned to WS 3 at 25677499
# Shipment 34 assigned to WS 3 at 25677499
# Shipment 35 assigned to WS 3 at 25677499
# Shipment 370 assigned to WS 2 at 25673876
# Shipment 371 assigned to WS 1 at 25673876
# Shipment 372 assigned to WS 1 at 25673876
# Shipment 373 assigned to WS 1 at 25673876
# Shipment 39 assigned to WS 1 at 25673505
# Shipment 40 assigned to WS 1 at 25673505
# Shipment 41 assigned to WS 1 at 25673505
# Shipment 51 assigned to WS 2 at 25675414
# Shipment 174 assigned to WS 1 at 25673355
# Shipment 184 assigned to WS 1 at 25673340
# Shipment 185 assigned to WS 1 at 25673340
# Shipment 195 assigned to WS 2 at 25675885
# Shipment 429 assigned to WS 3 at 25674265
# Shipment 430 assigned to WS 3 at 25674265
# Shipment 453 assigned to WS 2 at 25673955
# Shipment 466 assigned to WS 1 at 25672584
# Shipment 468 assigned to WS 2 at 25673405
# Shipment 470 assigned to WS 1 at 25673396
# Shipment 42 assigned to WS 1 at 25673505
# Shipment 43 assigned to WS 1 at 25673505
# Shipment 44 assigned to WS 1 at 25673505
# Shipment 347 assigned to WS 1 at 25672436
# Shipment 45 assigned to WS 1 at 25673505
# Shipment 46 assigned to WS 1 at 25673505
# Shipment 47 assigned to WS 1 at 25673505
# Shipment 52 assigned to WS 2 at 25675414
# Shipment 53 assigned to WS 2 at 25675414
# Shipment 76 assigned to WS 1 at 25673537
# Shipment 107 assigned to WS 2 at 25677353
# Shipment 108 assigned to WS 2 at 25677353
# Shipment 143 assigned to WS 1 at 25674912
# Shipment 176 assigned to WS 1 at 25673355
# Shipment 455 assigned to WS 2 at 25673955
# Shipment 472 assigned to WS 2 at 25673939
# Shipment 54 assigned to WS 2 at 25675414
# Shipment 55 assigned to WS 2 at 25675414
# Shipment 447 assigned to WS 3 at 25674806
# Shipment 448 assigned to WS 3 at 25674806
# Shipment 57 assigned to WS 2 at 25675414
# Shipment 58 assigned to WS 2 at 25675414
# Shipment 59 assigned to WS 2 at 25675414
# Shipment 60 assigned to WS 2 at 25675414
# Shipment 61 assigned to WS 2 at 25675414
# Shipment 62 assigned to WS 2 at 25675414
# Shipment 63 assigned to WS 2 at 25675414
# Shipment 64 assigned to WS 2 at 25675414
# Shipment 65 assigned to WS 2 at 25675414
# Shipment 337 assigned to WS 3 at 25681076
# Shipment 338 assigned to WS 3 at 25681076
# Shipment 339 assigned to WS 2 at 25681135
# Shipment 67 assigned to WS 3 at 25674397
# Shipment 509 assigned to WS 2 at 25674980
# Shipment 68 assigned to WS 3 at 25674397
# Shipment 252 assigned to WS 1 at 25672436
# Shipment 556 assigned to WS 3 at 25673484
# Shipment 69 assigned to WS 3 at 25674397
# Shipment 383 assigned to WS 2 at 25673740
# Shipment 70 assigned to WS 3 at 25674397
# Shipment 71 assigned to WS 3 at 25674397
# Shipment 72 assigned to WS 3 at 25674397
# Shipment 73 assigned to WS 3 at 25674397
# Shipment 78 assigned to WS 1 at 25673537
# Shipment 79 assigned to WS 1 at 25673537
# Shipment 80 assigned to WS 1 at 25673537
# Shipment 81 assigned to WS 1 at 25673537
# Shipment 304 assigned to WS 1 at 25681076
# Shipment 305 assigned to WS 1 at 25681076
# Shipment 306 assigned to WS 1 at 25681076
# Shipment 307 assigned to WS 2 at 25681076
# Shipment 308 assigned to WS 2 at 25681076
# Shipment 83 assigned to WS 1 at 25676163
# Shipment 368 assigned to WS 3 at 25681135
# Shipment 84 assigned to WS 1 at 25676163
# Shipment 86 assigned to WS 1 at 25676983
# Shipment 151 assigned to WS 2 at 25673682
# Shipment 274 assigned to WS 1 at 25672436
# Shipment 547 assigned to WS 1 at 25673349
# Shipment 87 assigned to WS 1 at 25676983
# Shipment 88 assigned to WS 2 at 25676983
# Shipment 451 assigned to WS 3 at 25674806
# Shipment 94 assigned to WS 3 at 25674669
# Shipment 111 assigned to WS 2 at 25677353
# Shipment 149 assigned to WS 2 at 25673682
# Shipment 96 assigned to WS 3 at 25674669
# Shipment 570 assigned to WS 1 at 25673912
# Shipment 631 assigned to WS 3 at 25673540
# Shipment 97 assigned to WS 3 at 25674669
# Shipment 98 assigned to WS 3 at 25674669
# Shipment 99 assigned to WS 3 at 25674669
# Shipment 100 assigned to WS 3 at 25674669
# Shipment 101 assigned to WS 3 at 25674669
# Shipment 102 assigned to WS 3 at 25674669
# Shipment 103 assigned to WS 3 at 25674669
# Shipment 104 assigned to WS 3 at 25674669
# Shipment 330 assigned to WS 2 at 25673876
# Shipment 331 assigned to WS 3 at 25673876
# Shipment 113 assigned to WS 1 at 25677353
# Shipment 334 assigned to WS 2 at 25681076
# Shipment 114 assigned to WS 1 at 25677353
# Shipment 115 assigned to WS 2 at 25677353
# Shipment 116 assigned to WS 3 at 25677353
# Shipment 117 assigned to WS 1 at 25677353
# Shipment 118 assigned to WS 2 at 25677353
# Shipment 119 assigned to WS 2 at 25677353
# Shipment 120 assigned to WS 2 at 25677353
# Shipment 375 assigned to WS 1 at 25681076
# Shipment 376 assigned to WS 1 at 25681076
# Shipment 122 assigned to WS 1 at 25673265
# Shipment 515 assigned to WS 2 at 25674980
# Shipment 568 assigned to WS 1 at 25673912
# Shipment 576 assigned to WS 1 at 25673376
# Shipment 123 assigned to WS 1 at 25673265
# Shipment 357 assigned to WS 2 at 25673876
# Shipment 124 assigned to WS 1 at 25673265
# Shipment 125 assigned to WS 3 at 25674423
# Shipment 128 assigned to WS 3 at 25676159
# Shipment 129 assigned to WS 3 at 25676159
# Shipment 130 assigned to WS 3 at 25676159
# Shipment 131 assigned to WS 3 at 25676159
# Shipment 132 assigned to WS 3 at 25676159
# Shipment 142 assigned to WS 1 at 25674912
# Shipment 146 assigned to WS 3 at 25673682
# Shipment 158 assigned to WS 2 at 25674560
# Shipment 160 assigned to WS 3 at 25674977
# Shipment 171 assigned to WS 1 at 25671844
# Shipment 173 assigned to WS 1 at 25673355
# Shipment 181 assigned to WS 1 at 25673272
# Shipment 126 assigned to WS 2 at 25674423
# Shipment 127 assigned to WS 2 at 25674423
# Shipment 133 assigned to WS 3 at 25676159
# Shipment 134 assigned to WS 3 at 25676159
# Shipment 280 assigned to WS 1 at 25672436
# Shipment 281 assigned to WS 1 at 25672436
# Shipment 384 assigned to WS 2 at 25673740
# Shipment 135 assigned to WS 3 at 25676159
# Shipment 136 assigned to WS 2 at 25676159
# Shipment 137 assigned to WS 3 at 25676159
# Shipment 138 assigned to WS 2 at 25676159
# Shipment 139 assigned to WS 3 at 25676159
# Shipment 140 assigned to WS 3 at 25676159
# Shipment 141 assigned to WS 3 at 25676159
# Shipment 144 assigned to WS 1 at 25674912
# Shipment 145 assigned to WS 1 at 25674912
# Shipment 340 assigned to WS 1 at 25681076
# Shipment 341 assigned to WS 3 at 25681076
# Shipment 147 assigned to WS 1 at 25673682
# Shipment 236 assigned to WS 1 at 25672436
# Shipment 237 assigned to WS 1 at 25672436
# Shipment 238 assigned to WS 1 at 25672436
# Shipment 148 assigned to WS 3 at 25673682
# Shipment 175 assigned to WS 1 at 25673355
# Shipment 186 assigned to WS 1 at 25673340
# Shipment 150 assigned to WS 3 at 25673682
# Shipment 152 assigned to WS 3 at 25673682
# Shipment 153 assigned to WS 1 at 25673682
# Shipment 155 assigned to WS 2 at 25673682
# Shipment 294 assigned to WS 1 at 25673876
# Shipment 295 assigned to WS 1 at 25673876
# Shipment 154 assigned to WS 2 at 25673682
# Shipment 156 assigned to WS 1 at 25673682
# Shipment 157 assigned to WS 2 at 25673682
# Shipment 159 assigned to WS 2 at 25674560
# Shipment 420 assigned to WS 3 at 25675661
# Shipment 421 assigned to WS 3 at 25675661
# Shipment 161 assigned to WS 1 at 25674977
# Shipment 250 assigned to WS 2 at 25672436
# Shipment 162 assigned to WS 3 at 25674977
# Shipment 540 assigned to WS 3 at 25675677
# Shipment 163 assigned to WS 2 at 25674977
# Shipment 164 assigned to WS 1 at 25674977
# Shipment 165 assigned to WS 3 at 25674977
# Shipment 166 assigned to WS 1 at 25674977
# Shipment 167 assigned to WS 2 at 25674977
# Shipment 297 assigned to WS 1 at 25681076
# Shipment 168 assigned to WS 1 at 25674977
# Shipment 169 assigned to WS 2 at 25674977
# Shipment 367 assigned to WS 3 at 25673876
# Shipment 170 assigned to WS 1 at 25674977
# Shipment 172 assigned to WS 1 at 25671844
# Shipment 177 assigned to WS 1 at 25673355
# Shipment 178 assigned to WS 1 at 25673355
# Shipment 353 assigned to WS 2 at 25673876
# Shipment 179 assigned to WS 1 at 25673355
# Shipment 180 assigned to WS 1 at 25673355
# Shipment 182 assigned to WS 1 at 25673272
# Shipment 183 assigned to WS 1 at 25673340
# Shipment 191 assigned to WS 1 at 25675103
# Shipment 193 assigned to WS 2 at 25675885
# Shipment 194 assigned to WS 2 at 25675885
# Shipment 202 assigned to WS 3 at 25674399
# Shipment 203 assigned to WS 3 at 25674399
# Shipment 206 assigned to WS 2 at 25672436
# Shipment 207 assigned to WS 1 at 25672436
# Shipment 208 assigned to WS 1 at 25672436
# Shipment 209 assigned to WS 1 at 25672436
# Shipment 210 assigned to WS 1 at 25672436
# Shipment 211 assigned to WS 1 at 25672436
# Shipment 212 assigned to WS 1 at 25672436
# Shipment 213 assigned to WS 1 at 25672436
# Shipment 214 assigned to WS 1 at 25672436
# Shipment 215 assigned to WS 3 at 25672436
# Shipment 381 assigned to WS 2 at 25673740
# Shipment 187 assigned to WS 1 at 25673340
# Shipment 188 assigned to WS 1 at 25673340
# Shipment 189 assigned to WS 1 at 25673340
# Shipment 355 assigned to WS 1 at 25673876
# Shipment 356 assigned to WS 1 at 25673876
# Shipment 190 assigned to WS 1 at 25673340
# Shipment 192 assigned to WS 1 at 25675103
# Shipment 336 assigned to WS 1 at 25681076
# Shipment 196 assigned to WS 2 at 25675885
# Shipment 197 assigned to WS 2 at 25675885
# Shipment 198 assigned to WS 2 at 25675885
# Shipment 199 assigned to WS 2 at 25675885
# Shipment 200 assigned to WS 2 at 25675885
# Shipment 201 assigned to WS 2 at 25675885
# Shipment 204 assigned to WS 3 at 25674399
# Shipment 205 assigned to WS 3 at 25674399
# Shipment 327 assigned to WS 3 at 25681076
# Shipment 216 assigned to WS 3 at 25673876
# Shipment 389 assigned to WS 3 at 25673716
# Shipment 217 assigned to WS 1 at 25673876
# Shipment 390 assigned to WS 1 at 25673716
# Shipment 224 assigned to WS 1 at 25681076
# Shipment 391 assigned to WS 1 at 25673716
# Shipment 234 assigned to WS 3 at 25681129
# Shipment 235 assigned to WS 1 at 25681076
# Shipment 396 assigned to WS 2 at 25673716
# Shipment 397 assigned to WS 1 at 25673716
# Shipment 239 assigned to WS 2 at 25681076
# Shipment 240 assigned to WS 3 at 25681129
# Shipment 241 assigned to WS 2 at 25681076
# Shipment 474 assigned to WS 3 at 25673830
# Shipment 475 assigned to WS 3 at 25673830
# Shipment 476 assigned to WS 2 at 25673830
# Shipment 477 assigned to WS 3 at 25673830
# Shipment 242 assigned to WS 1 at 25672436
# Shipment 482 assigned to WS 1 at 25674037
# Shipment 244 assigned to WS 2 at 25672436
# Shipment 245 assigned to WS 1 at 25672436
# Shipment 246 assigned to WS 3 at 25672492
# Shipment 247 assigned to WS 3 at 25672436
# Shipment 431 assigned to WS 3 at 25674265
# Shipment 432 assigned to WS 3 at 25674265
# Shipment 248 assigned to WS 3 at 25672492
# Shipment 545 assigned to WS 1 at 25673349
# Shipment 249 assigned to WS 3 at 25672436
# Shipment 251 assigned to WS 1 at 25672436
# Shipment 253 assigned to WS 1 at 25672495
# Shipment 254 assigned to WS 2 at 25672436
# Shipment 483 assigned to WS 1 at 25674037
# Shipment 255 assigned to WS 1 at 25672436
# Shipment 560 assigned to WS 2 at 25674265
# Shipment 256 assigned to WS 3 at 25681129
# Shipment 587 assigned to WS 3 at 25674106
# Shipment 257 assigned to WS 3 at 25681076
# Shipment 258 assigned to WS 2 at 25681135
# Shipment 259 assigned to WS 1 at 25673876
# Shipment 260 assigned to WS 2 at 25672436
# Shipment 569 assigned to WS 1 at 25673912
# Shipment 261 assigned to WS 2 at 25673876
# Shipment 618 assigned to WS 3 at 25679663
# Shipment 265 assigned to WS 1 at 25672436
# Shipment 266 assigned to WS 3 at 25672495
# Shipment 267 assigned to WS 2 at 25673876
# Shipment 268 assigned to WS 2 at 25673876
# Shipment 269 assigned to WS 2 at 25681076
# Shipment 270 assigned to WS 3 at 25681129
# Shipment 271 assigned to WS 2 at 25681076
# Shipment 272 assigned to WS 2 at 25681076
# Shipment 273 assigned to WS 2 at 25681076
# Shipment 275 assigned to WS 1 at 25681135
# Shipment 276 assigned to WS 1 at 25672436
# Shipment 277 assigned to WS 1 at 25672436
# Shipment 571 assigned to WS 1 at 25673912
# Shipment 610 assigned to WS 1 at 25673089
# Shipment 637 assigned to WS 1 at 25673056
# Shipment 639 assigned to WS 1 at 25676358
# Shipment 641 assigned to WS 3 at 25674737
# Shipment 278 assigned to WS 3 at 25673876
# Shipment 279 assigned to WS 1 at 25673876
# Shipment 595 assigned to WS 3 at 25674729
# Shipment 596 assigned to WS 2 at 25674729
# Shipment 282 assigned to WS 1 at 25672436
# Shipment 283 assigned to WS 1 at 25673876
# Shipment 284 assigned to WS 2 at 25681076
# Shipment 597 assigned to WS 2 at 25674729
# Shipment 285 assigned to WS 1 at 25681076
# Shipment 598 assigned to WS 2 at 25674729
# Shipment 599 assigned to WS 2 at 25674729
# Shipment 600 assigned to WS 2 at 25674729
# Shipment 288 assigned to WS 3 at 25672492
# Shipment 289 assigned to WS 1 at 25672436
# Shipment 290 assigned to WS 1 at 25673876
# Shipment 655 assigned to WS 3 at 25674733
# Shipment 656 assigned to WS 3 at 25674733
# Shipment 291 assigned to WS 2 at 25672436
# Shipment 292 assigned to WS 3 at 25672436
# Shipment 293 assigned to WS 3 at 25672436
# Shipment 665 assigned to WS 3 at 25676029
# Shipment 296 assigned to WS 3 at 25681076
# Shipment 385 assigned to WS 2 at 25673740
# Shipment 386 assigned to WS 2 at 25673740
# Shipment 387 assigned to WS 2 at 25673740
# Shipment 298 assigned to WS 2 at 25673876
# Shipment 299 assigned to WS 1 at 25673876
# Shipment 300 assigned to WS 1 at 25673876
# Shipment 301 assigned to WS 2 at 25673876
# Shipment 302 assigned to WS 2 at 25673876
# Shipment 572 assigned to WS 1 at 25673912
# Shipment 573 assigned to WS 1 at 25673912
# Shipment 574 assigned to WS 1 at 25673912
# Shipment 575 assigned to WS 1 at 25673912
# Shipment 303 assigned to WS 1 at 25672436
# Shipment 458 assigned to WS 2 at 25673955
# Shipment 459 assigned to WS 2 at 25673955
# Shipment 309 assigned to WS 3 at 25673876
# Shipment 310 assigned to WS 2 at 25673876
# Shipment 411 assigned to WS 3 at 25673774
# Shipment 311 assigned to WS 2 at 25681076
# Shipment 649 assigned to WS 1 at 25672504
# Shipment 650 assigned to WS 1 at 25672504
# Shipment 312 assigned to WS 1 at 25673876
# Shipment 313 assigned to WS 3 at 25681076
# Shipment 542 assigned to WS 3 at 25675677
# Shipment 543 assigned to WS 3 at 25675677
# Shipment 314 assigned to WS 1 at 25672436
# Shipment 566 assigned to WS 1 at 25674841
# Shipment 315 assigned to WS 1 at 25673876
# Shipment 316 assigned to WS 1 at 25673876
# Shipment 317 assigned to WS 3 at 25673876
# Shipment 318 assigned to WS 1 at 25673876
# Shipment 319 assigned to WS 1 at 25673876
# Shipment 424 assigned to WS 3 at 25675661
# Shipment 425 assigned to WS 3 at 25675661
# Shipment 522 assigned to WS 3 at 25674980
# Shipment 320 assigned to WS 1 at 25681076
# Shipment 321 assigned to WS 1 at 25681135
# Shipment 322 assigned to WS 2 at 25673876
# Shipment 323 assigned to WS 2 at 25673876
# Shipment 484 assigned to WS 1 at 25674037
# Shipment 485 assigned to WS 1 at 25674037
# Shipment 324 assigned to WS 2 at 25673876
# Shipment 487 assigned to WS 2 at 25673295
# Shipment 325 assigned to WS 2 at 25681076
# Shipment 326 assigned to WS 2 at 25681076
# Shipment 328 assigned to WS 1 at 25672436
# Shipment 414 assigned to WS 3 at 25673716
# Shipment 329 assigned to WS 2 at 25673876
# Shipment 449 assigned to WS 3 at 25674806
# Shipment 450 assigned to WS 3 at 25674806
# Shipment 332 assigned to WS 1 at 25673876
# Shipment 333 assigned to WS 1 at 25673876
# Shipment 335 assigned to WS 2 at 25672436
# Shipment 342 assigned to WS 1 at 25681076
# Shipment 343 assigned to WS 2 at 25681076
# Shipment 344 assigned to WS 2 at 25681076
# Shipment 345 assigned to WS 2 at 25681135
# Shipment 346 assigned to WS 1 at 25673876
# Shipment 348 assigned to WS 2 at 25672436
# Shipment 663 assigned to WS 2 at 25674733
# Shipment 349 assigned to WS 1 at 25672436
# Shipment 350 assigned to WS 1 at 25681076
# Shipment 351 assigned to WS 1 at 25673876
# Shipment 460 assigned to WS 2 at 25673955
# Shipment 461 assigned to WS 2 at 25673955
# Shipment 462 assigned to WS 2 at 25673955
# Shipment 463 assigned to WS 2 at 25673955
# Shipment 352 assigned to WS 1 at 25672436
# Shipment 354 assigned to WS 1 at 25673876
# Shipment 577 assigned to WS 1 at 25673376
# Shipment 358 assigned to WS 2 at 25673876
# Shipment 359 assigned to WS 1 at 25672436
# Shipment 360 assigned to WS 2 at 25681076
# Shipment 361 assigned to WS 3 at 25673876
# Shipment 644 assigned to WS 2 at 25674481
# Shipment 362 assigned to WS 1 at 25672436
# Shipment 363 assigned to WS 2 at 25672495
# Shipment 364 assigned to WS 3 at 25681076
# Shipment 365 assigned to WS 1 at 25681076
# Shipment 366 assigned to WS 3 at 25681076
# Shipment 497 assigned to WS 1 at 25674734
# Shipment 604 assigned to WS 2 at 25674729
# Shipment 369 assigned to WS 1 at 25673876
# Shipment 552 assigned to WS 1 at 25673349
# Shipment 374 assigned to WS 2 at 25681076
# Shipment 567 assigned to WS 1 at 25674841
# Shipment 377 assigned to WS 1 at 25672436
# Shipment 613 assigned to WS 1 at 25673089
# Shipment 378 assigned to WS 3 at 25681135
# Shipment 379 assigned to WS 3 at 25681076
# Shipment 380 assigned to WS 2 at 25681076
# Shipment 544 assigned to WS 3 at 25675677
# Shipment 382 assigned to WS 2 at 25673740
# Shipment 388 assigned to WS 3 at 25673716
# Shipment 392 assigned to WS 1 at 25673716
# Shipment 393 assigned to WS 1 at 25673716
# Shipment 394 assigned to WS 1 at 25673773
# Shipment 395 assigned to WS 1 at 25673716
# Shipment 398 assigned to WS 2 at 25673716
# Shipment 399 assigned to WS 1 at 25673773
# Shipment 400 assigned to WS 3 at 25673775
# Shipment 401 assigned to WS 3 at 25673716
# Shipment 402 assigned to WS 2 at 25673716
# Shipment 493 assigned to WS 2 at 25674734
# Shipment 619 assigned to WS 3 at 25679663
# Shipment 403 assigned to WS 3 at 25673716
# Shipment 404 assigned to WS 2 at 25673716
# Shipment 405 assigned to WS 2 at 25673716
# Shipment 406 assigned to WS 2 at 25673716
# Shipment 478 assigned to WS 3 at 25673830
# Shipment 518 assigned to WS 1 at 25674980
# Shipment 407 assigned to WS 1 at 25673716
# Shipment 520 assigned to WS 1 at 25674980
# Shipment 521 assigned to WS 1 at 25674980
# Shipment 554 assigned to WS 2 at 25674075
# Shipment 601 assigned to WS 3 at 25674729
# Shipment 660 assigned to WS 1 at 25674733
# Shipment 408 assigned to WS 2 at 25673716
# Shipment 409 assigned to WS 1 at 25673716
# Shipment 410 assigned to WS 1 at 25673773
# Shipment 412 assigned to WS 2 at 25673775
# Shipment 413 assigned to WS 1 at 25673716
# Shipment 415 assigned to WS 3 at 25673716
# Shipment 480 assigned to WS 3 at 25673830
# Shipment 416 assigned to WS 2 at 25673716
# Shipment 417 assigned to WS 2 at 25673716
# Shipment 418 assigned to WS 2 at 25673716
# Shipment 654 assigned to WS 3 at 25675563
# Shipment 422 assigned to WS 3 at 25675661
# Shipment 423 assigned to WS 3 at 25675661
# Shipment 426 assigned to WS 2 at 25675661
# Shipment 433 assigned to WS 3 at 25674265
# Shipment 434 assigned to WS 3 at 25674265
# Shipment 435 assigned to WS 3 at 25674265
# Shipment 436 assigned to WS 3 at 25674265
# Shipment 437 assigned to WS 3 at 25674265
# Shipment 439 assigned to WS 3 at 25673942
# Shipment 441 assigned to WS 3 at 25674236
# Shipment 442 assigned to WS 3 at 25674236
# Shipment 443 assigned to WS 3 at 25674236
# Shipment 445 assigned to WS 2 at 25673246
# Shipment 456 assigned to WS 2 at 25673955
# Shipment 457 assigned to WS 2 at 25673955
# Shipment 464 assigned to WS 2 at 25673955
# Shipment 465 assigned to WS 2 at 25673955
# Shipment 467 assigned to WS 1 at 25672584
# Shipment 469 assigned to WS 2 at 25673405
# Shipment 471 assigned to WS 1 at 25673396
# Shipment 473 assigned to WS 2 at 25673939
# Shipment 479 assigned to WS 3 at 25673830
# Shipment 589 assigned to WS 2 at 25674106
# Shipment 481 assigned to WS 3 at 25673830
# Shipment 488 assigned to WS 3 at 25674734
# Shipment 489 assigned to WS 3 at 25674734
# Shipment 490 assigned to WS 2 at 25674734
# Shipment 491 assigned to WS 1 at 25674734
# Shipment 492 assigned to WS 3 at 25674734
# Shipment 494 assigned to WS 2 at 25674734
# Shipment 495 assigned to WS 1 at 25674734
# Shipment 496 assigned to WS 2 at 25674734
# Shipment 611 assigned to WS 1 at 25673089
# Shipment 498 assigned to WS 3 at 25673310
# Shipment 500 assigned to WS 1 at 25673506
# Shipment 501 assigned to WS 1 at 25673506
# Shipment 499 assigned to WS 3 at 25673310
# Shipment 502 assigned to WS 1 at 25673506
# Shipment 503 assigned to WS 1 at 25673506
# Shipment 504 assigned to WS 1 at 25674980
# Shipment 505 assigned to WS 1 at 25674980
# Shipment 533 assigned to WS 2 at 25674367
# Shipment 536 assigned to WS 1 at 25673921
# Shipment 506 assigned to WS 1 at 25674980
# Shipment 507 assigned to WS 3 at 25674980
# Shipment 508 assigned to WS 1 at 25674980
# Shipment 539 assigned to WS 3 at 25675677
# Shipment 510 assigned to WS 1 at 25674980
# Shipment 511 assigned to WS 1 at 25674980
# Shipment 512 assigned to WS 2 at 25674980
# Shipment 513 assigned to WS 3 at 25674980
# Shipment 553 assigned to WS 2 at 25674075
# Shipment 514 assigned to WS 3 at 25674980
# Shipment 516 assigned to WS 1 at 25675038
# Shipment 517 assigned to WS 1 at 25674980
# Shipment 519 assigned to WS 1 at 25674980
# Shipment 523 assigned to WS 1 at 25674980
# Shipment 524 assigned to WS 2 at 25674980
# Shipment 525 assigned to WS 1 at 25674980
# Shipment 664 assigned to WS 2 at 25674733
# Shipment 526 assigned to WS 2 at 25674980
# Shipment 527 assigned to WS 1 at 25674980
# Shipment 528 assigned to WS 3 at 25674980
# Shipment 529 assigned to WS 3 at 25674980
# Shipment 530 assigned to WS 1 at 25674980
# Shipment 531 assigned to WS 3 at 25674980
# Shipment 555 assigned to WS 2 at 25674075
# Shipment 532 assigned to WS 1 at 25674980
# Shipment 605 assigned to WS 2 at 25674729
# Shipment 534 assigned to WS 2 at 25674367
# Shipment 535 assigned to WS 2 at 25674367
# Shipment 537 assigned to WS 2 at 25673921
# Shipment 538 assigned to WS 3 at 25673921
# Shipment 546 assigned to WS 1 at 25673349
# Shipment 557 assigned to WS 3 at 25673484
# Shipment 578 assigned to WS 1 at 25673210
# Shipment 582 assigned to WS 2 at 25673813
# Shipment 548 assigned to WS 1 at 25673349
# Shipment 549 assigned to WS 1 at 25673349
# Shipment 550 assigned to WS 1 at 25673349
# Shipment 551 assigned to WS 1 at 25673349
# Shipment 558 assigned to WS 3 at 25673484
# Shipment 559 assigned to WS 3 at 25673484
# Shipment 561 assigned to WS 2 at 25674265
# Shipment 667 assigned to WS 2 at 25671958
# Shipment 562 assigned to WS 2 at 25674265
# Shipment 563 assigned to WS 2 at 25674265
# Shipment 564 assigned to WS 2 at 25674265
# Shipment 565 assigned to WS 1 at 25674841
# Shipment 579 assigned to WS 1 at 25673210
# Shipment 580 assigned to WS 1 at 25673210
# Shipment 581 assigned to WS 1 at 25673210
# Shipment 583 assigned to WS 2 at 25673813
# Shipment 584 assigned to WS 1 at 25676200
# Shipment 585 assigned to WS 1 at 25676200
# Shipment 586 assigned to WS 1 at 25676200
# Shipment 588 assigned to WS 3 at 25674106
# Shipment 590 assigned to WS 3 at 25674106
# Shipment 607 assigned to WS 2 at 25674729
# Shipment 591 assigned to WS 3 at 25674850
# Shipment 592 assigned to WS 3 at 25674850
# Shipment 593 assigned to WS 3 at 25674729
# Shipment 594 assigned to WS 3 at 25674729
# Shipment 602 assigned to WS 2 at 25674729
# Shipment 603 assigned to WS 3 at 25674729
# Shipment 606 assigned to WS 3 at 25674729
# Shipment 608 assigned to WS 1 at 25673089
# Shipment 609 assigned to WS 1 at 25673089
# Shipment 612 assigned to WS 1 at 25673089
# Shipment 614 assigned to WS 3 at 25679663
# Shipment 615 assigned to WS 3 at 25679663
# Shipment 616 assigned to WS 2 at 25679663
# Shipment 617 assigned to WS 3 at 25679663
# Shipment 620 assigned to WS 3 at 25679663
# Shipment 621 assigned to WS 3 at 25679663
# Shipment 622 assigned to WS 3 at 25679663
# Shipment 623 assigned to WS 3 at 25679663
# Shipment 624 assigned to WS 3 at 25679663
# Shipment 626 assigned to WS 3 at 25672503
# Shipment 627 assigned to WS 3 at 25673160
# Shipment 628 assigned to WS 3 at 25673160
# Shipment 629 assigned to WS 3 at 25673160
# Shipment 630 assigned to WS 2 at 25673160
# Shipment 633 assigned to WS 3 at 25673540
# Shipment 634 assigned to WS 3 at 25673540
# Shipment 635 assigned to WS 2 at 25674286
# Shipment 636 assigned to WS 2 at 25674286
# Shipment 638 assigned to WS 1 at 25673056
# Shipment 640 assigned to WS 1 at 25676358
# Shipment 642 assigned to WS 3 at 25674737
# Shipment 646 assigned to WS 2 at 25680782
# Shipment 651 assigned to WS 3 at 25675563
# Shipment 652 assigned to WS 3 at 25675563
# Shipment 653 assigned to WS 3 at 25675563
# Shipment 668 assigned to WS 2 at 25671958
# Shipment 657 assigned to WS 1 at 25674733
# Shipment 658 assigned to WS 2 at 25674733
# Shipment 659 assigned to WS 3 at 25674733
# Shipment 661 assigned to WS 1 at 25674733
# Shipment 662 assigned to WS 2 at 25674733
# Shipment 666 assigned to WS 3 at 25676029

# %%
sample_shipments_bu
# Out:
#      Shipment ID ProductName  Priority   DropZone  ArrivalULDNumber  Pieces  Weight  TotalWeight  FlightNumberDeparture     key_shipment_id_arrival_date Shipment_arrival_date_time Shipment_departure_date_time Shipment_duration build_up_arrival_time build_up_finish_time  FlightNumber_x    BU Zone TransportationDistance  transport_dist_h  transport_dist_m  transport_dist_s DefaultProcessingTime  default_h  default_m  default_s     Name_x HandlingTimePerULD TransportationTimeToWH     Name_y  Count  handling_ULD_h  handling_ULD_m  handling_ULD_s  transport_WH_h  transport_WH_m  transport_WH_s  ULD_handling_h  ULD_handling_m  ULD_handling_s arrival_date departure_date  Shipment_duration_minutes  Shipment_arrival_time_minutes  Shipment_departure_time_minutes   day_name flight_pre_id  FlightNumber_y Weekday PreProcessingBufferTime       day  Pre_h  Pre_m  Pre_s  new_departure_time  shipment_ID       unique_id
# 0   020-77215633        NRML     False  DZ NRML-2             21231       1    26.2         26.2                      3  020-772156332018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-25 05:15:00   1 days 23:05:00   2018-10-23 06:10:00  2018-10-25 05:15:00               3    BU FT-1               00:19:00                 0                19                 0              00:10:00          0         10          0    BU FT-1           00:24:00               00:50:00    BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-23     2018-10-25                       2825                       25671250                         25673932   Thursday    3_Thursday               3       *                00:10:00  Thursday      0     10      0            25673932            1  21231_25671250
# 1   020-77215515        NRML     False  DZ NRML-2             21231       1     5.5          5.5                      4  020-772155152018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-27 13:45:00   4 days 07:35:00   2018-10-23 06:10:00  2018-10-27 13:45:00               4    BU FT-1               00:24:00                 0                24                 0              00:25:00          0         25          0    BU FT-1           00:24:00               00:50:00    BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-23     2018-10-27                       6215                       25671250                         25677312   Saturday    4_Saturday               0       0                       0         0      0      0      0            25677312            2  21231_25671250
# 2   020-84100306         NML     False   DZ NML-1             21231       1     2.6          2.6                      7  020-841003062018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-24 21:20:00   1 days 15:10:00   2018-10-23 06:10:00  2018-10-24 21:20:00               7    BU FT-2               00:19:00                 0                19                 0              00:10:00          0         10          0    BU FT-2           00:24:00               00:45:00    BU FT-2      6               0              24               0               0              45               0               0              24               0   2018-10-23     2018-10-24                       2350                       25671250                         25673472  Wednesday   7_Wednesday               0       0                       0         0      0      0      0            25673472            3  21231_25671250
# 3   020-82036091        NRML     False  DZ NRML-2             21231       1     1.7          1.7                      9  020-820360912018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-27 17:20:00   4 days 11:10:00   2018-10-23 06:10:00  2018-10-27 17:20:00               9    BU FT-2               00:07:00                 0                 7                 0              00:15:00          0         15          0    BU FT-2           00:24:00               00:45:00    BU FT-2      6               0              24               0               0              45               0               0              24               0   2018-10-23     2018-10-27                       6430                       25671250                         25677559   Saturday    9_Saturday               0       0                       0         0      0      0      0            25677559            4  21231_25671250
# 4   020-84368815        NRML     False  DZ NRML-2             21231       1    22.6         22.6                     46  020-843688152018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-24 23:00:00   1 days 16:50:00   2018-10-23 06:10:00  2018-10-24 23:00:00              46  BU NRML-1               00:20:00                 0                20                 0              00:15:00          0         15          0  BU NRML-1           00:20:00               00:50:00  BU NRML-1      3               0              20               0               0              50               0               0              20               0   2018-10-23     2018-10-24                       2450                       25671250                         25673565  Wednesday  46_Wednesday               0       0                       0         0      0      0      0            25673565            5  21231_25671250
# 5   020-84368841        NRML     False  DZ NRML-2             21231       3    15.5         15.5                     46  020-843688412018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-24 23:00:00   1 days 16:50:00   2018-10-23 06:10:00  2018-10-24 23:00:00              46  BU NRML-1               00:20:00                 0                20                 0              00:15:00          0         15          0  BU NRML-1           00:20:00               00:50:00  BU NRML-1      3               0              20               0               0              50               0               0              20               0   2018-10-23     2018-10-24                       2450                       25671250                         25673565  Wednesday  46_Wednesday               0       0                       0         0      0      0      0            25673565            6  21231_25671250
# 6   020-84368830        NRML     False  DZ NRML-2             21231       1    22.3         22.3                     46  020-843688302018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-24 23:00:00   1 days 16:50:00   2018-10-23 06:10:00  2018-10-24 23:00:00              46  BU NRML-1               00:20:00                 0                20                 0              00:15:00          0         15          0  BU NRML-1           00:20:00               00:50:00  BU NRML-1      3               0              20               0               0              50               0               0              20               0   2018-10-23     2018-10-24                       2450                       25671250                         25673565  Wednesday  46_Wednesday               0       0                       0         0      0      0      0            25673565            7  21231_25671250
# 7   020-83534161        NRML     False  DZ NRML-2             21231       2     1.9          1.9                     60  020-835341612018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-26 06:45:00   3 days 00:35:00   2018-10-23 06:10:00  2018-10-26 06:45:00              60  BU NRML-3               00:26:00                 0                26                 0              00:15:00          0         15          0  BU NRML-3           00:20:00               00:40:00  BU NRML-3      3               0              20               0               0              40               0               0              20               0   2018-10-23     2018-10-26                       4355                       25671250                         25675474     Friday     60_Friday               0       0                       0         0      0      0      0            25675474            8  21231_25671250
# 8   020-77215482        NRML     False  DZ NRML-2             21231       1    11.1         11.1                     60  020-772154822018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-26 06:45:00   3 days 00:35:00   2018-10-23 06:10:00  2018-10-26 06:45:00              60  BU NRML-3               00:26:00                 0                26                 0              00:15:00          0         15          0  BU NRML-3           00:20:00               00:40:00  BU NRML-3      3               0              20               0               0              40               0               0              20               0   2018-10-23     2018-10-26                       4355                       25671250                         25675474     Friday     60_Friday               0       0                       0         0      0      0      0            25675474            9  21231_25671250
# 9   020-77215644        NRML     False  DZ NRML-2             21231       1     0.2          0.2                     60  020-772156442018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-26 06:45:00   3 days 00:35:00   2018-10-23 06:10:00  2018-10-26 06:45:00              60  BU NRML-3               00:26:00                 0                26                 0              00:15:00          0         15          0  BU NRML-3           00:20:00               00:40:00  BU NRML-3      3               0              20               0               0              40               0               0              20               0   2018-10-23     2018-10-26                       4355                       25671250                         25675474     Friday     60_Friday               0       0                       0         0      0      0      0            25675474           10  21231_25671250
# 10  020-82036102        NRML     False  DZ NRML-2             21231       1    34.8         34.8                     61  020-820361022018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-25 13:30:00   2 days 07:20:00   2018-10-23 06:10:00  2018-10-25 13:30:00              61  BU NRML-3               00:08:00                 0                 8                 0              00:15:00          0         15          0  BU NRML-3           00:20:00               00:40:00  BU NRML-3      3               0              20               0               0              40               0               0              20               0   2018-10-23     2018-10-25                       3320                       25671250                         25674457   Thursday   61_Thursday               0       0                       0         0      0      0      0            25674457           11  21231_25671250
# 11  020-77215622        NRML     False  DZ NRML-2             21231       1     5.6          5.6                     62  020-772156222018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-24 23:30:00   1 days 17:20:00   2018-10-23 06:10:00  2018-10-24 23:30:00              62  BU NRML-3               00:28:00                 0                28                 0              00:15:00          0         15          0  BU NRML-3           00:20:00               00:40:00  BU NRML-3      3               0              20               0               0              40               0               0              20               0   2018-10-23     2018-10-24                       2480                       25671250                         25673597  Wednesday  62_Wednesday               0       0                       0         0      0      0      0            25673597           12  21231_25671250
# 12  020-77215655        NRML     False  DZ NRML-2             21231       1     1.6          1.6                     62  020-772156552018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-24 23:30:00   1 days 17:20:00   2018-10-23 06:10:00  2018-10-24 23:30:00              62  BU NRML-3               00:28:00                 0                28                 0              00:15:00          0         15          0  BU NRML-3           00:20:00               00:40:00  BU NRML-3      3               0              20               0               0              40               0               0              20               0   2018-10-23     2018-10-24                       2480                       25671250                         25673597  Wednesday  62_Wednesday               0       0                       0         0      0      0      0            25673597           13  21231_25671250
# 13  020-84364545        NRML     False  DZ NRML-2             21231       1    76.6         76.6                     63  020-843645452018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-26 19:10:00   3 days 13:00:00   2018-10-23 06:10:00  2018-10-26 19:10:00              63  BU NRML-3               00:22:00                 0                22                 0              00:15:00          0         15          0  BU NRML-3           00:20:00               00:40:00  BU NRML-3      3               0              20               0               0              40               0               0              20               0   2018-10-23     2018-10-26                       5100                       25671250                         25676223     Friday     63_Friday               0       0                       0         0      0      0      0            25676223           14  21231_25671250
# 14  020-77215493        NRML     False  DZ NRML-2             21231       1    24.9         24.9                     64  020-772154932018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-27 08:30:00   4 days 02:20:00   2018-10-23 06:10:00  2018-10-27 08:30:00              64  BU NRML-3               00:02:00                 0                 2                 0              00:15:00          0         15          0  BU NRML-3           00:20:00               00:40:00  BU NRML-3      3               0              20               0               0              40               0               0              20               0   2018-10-23     2018-10-27                       5900                       25671250                         25677043   Saturday   64_Saturday               0       0                       0         0      0      0      0            25677043           15  21231_25671250
# 15  020-88025162        NRML     False  DZ NRML-2             51228       1   240.7        240.7                     64  020-880251622018-10-23T08:00:00        2018-10-23 08:00:00          2018-10-27 08:30:00   4 days 00:30:00   2018-10-23 08:00:00  2018-10-27 08:30:00              64  BU NRML-3               00:02:00                 0                 2                 0              00:15:00          0         15          0  BU NRML-3           00:20:00               00:40:00  BU NRML-3      3               0              20               0               0              40               0               0              20               0   2018-10-23     2018-10-27                       5790                       25671360                         25677043   Saturday   64_Saturday               0       0                       0         0      0      0      0            25677043           16  51228_25671360
# 16  020-84368723        NRML     False  DZ NRML-2             21231       1     1.8          1.8                     65  020-843687232018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-25 18:20:00   2 days 12:10:00   2018-10-23 06:10:00  2018-10-25 18:20:00              65  BU NRML-3               00:26:00                 0                26                 0              00:15:00          0         15          0  BU NRML-3           00:20:00               00:40:00  BU NRML-3      3               0              20               0               0              40               0               0              20               0   2018-10-23     2018-10-25                       3610                       25671250                         25674729   Thursday   65_Thursday               0       0                       0         0      0      0      0            25674729           17  21231_25671250
# 17  020-84368756        NRML     False  DZ NRML-2             21231       1     2.8          2.8                     65  020-843687562018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-25 18:20:00   2 days 12:10:00   2018-10-23 06:10:00  2018-10-25 18:20:00              65  BU NRML-3               00:26:00                 0                26                 0              00:15:00          0         15          0  BU NRML-3           00:20:00               00:40:00  BU NRML-3      3               0              20               0               0              40               0               0              20               0   2018-10-23     2018-10-25                       3610                       25671250                         25674729   Thursday   65_Thursday               0       0                       0         0      0      0      0            25674729           18  21231_25671250
# 18  020-84368550        NRML     False  DZ NRML-2             21231       1     0.5          0.5                     65  020-843685502018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-25 18:20:00   2 days 12:10:00   2018-10-23 06:10:00  2018-10-25 18:20:00              65  BU NRML-3               00:26:00                 0                26                 0              00:15:00          0         15          0  BU NRML-3           00:20:00               00:40:00  BU NRML-3      3               0              20               0               0              40               0               0              20               0   2018-10-23     2018-10-25                       3610                       25671250                         25674729   Thursday   65_Thursday               0       0                       0         0      0      0      0            25674729           19  21231_25671250
# 19  020-96790805        NRML     False  DZ NRML-2             21231       1     4.4          4.4                     65  020-967908052018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-25 18:20:00   2 days 12:10:00   2018-10-23 06:10:00  2018-10-25 18:20:00              65  BU NRML-3               00:26:00                 0                26                 0              00:15:00          0         15          0  BU NRML-3           00:20:00               00:40:00  BU NRML-3      3               0              20               0               0              40               0               0              20               0   2018-10-23     2018-10-25                       3610                       25671250                         25674729   Thursday   65_Thursday               0       0                       0         0      0      0      0            25674729           20  21231_25671250
# 20  020-84368760        NRML     False  DZ NRML-2             21231       1     0.5          0.5                     65  020-843687602018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-25 18:20:00   2 days 12:10:00   2018-10-23 06:10:00  2018-10-25 18:20:00              65  BU NRML-3               00:26:00                 0                26                 0              00:15:00          0         15          0  BU NRML-3           00:20:00               00:40:00  BU NRML-3      3               0              20               0               0              40               0               0              20               0   2018-10-23     2018-10-25                       3610                       25671250                         25674729   Thursday   65_Thursday               0       0                       0         0      0      0      0            25674729           21  21231_25671250
# 21  020-83518153        NRML     False  DZ NRML-2             21231       1    90.5         90.5                     66  020-835181532018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-27 14:50:00   4 days 08:40:00   2018-10-23 06:10:00  2018-10-27 14:50:00              66  BU NRML-3               00:12:00                 0                12                 0              00:15:00          0         15          0  BU NRML-3           00:20:00               00:40:00  BU NRML-3      3               0              20               0               0              40               0               0              20               0   2018-10-23     2018-10-27                       6280                       25671250                         25677413   Saturday   66_Saturday               0       0                       0         0      0      0      0            25677413           22  21231_25671250
# 22  020-83678195         NML      True   DZ NML-1             21231       1    49.8         49.8                     66  020-836781952018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-27 14:50:00   4 days 08:40:00   2018-10-23 06:10:00  2018-10-27 14:50:00              66  BU NRML-3               00:12:00                 0                12                 0              00:15:00          0         15          0  BU NRML-3           00:20:00               00:40:00  BU NRML-3      3               0              20               0               0              40               0               0              20               0   2018-10-23     2018-10-27                       6280                       25671250                         25677413   Saturday   66_Saturday               0       0                       0         0      0      0      0            25677413           23  21231_25671250
# 23  020-77215471        NRML     False  DZ NRML-2             21231       1     0.3          0.3                     67  020-772154712018-10-23T06:10:00        2018-10-23 06:10:00          2018-10-24 19:05:00   1 days 12:55:00   2018-10-23 06:10:00  2018-10-24 19:05:00              67  BU NRML-3               00:25:00                 0                25                 0              00:25:00          0         25          0  BU NRML-3           00:20:00               00:40:00  BU NRML-3      3               0              20               0               0              40               0               0              20               0   2018-10-23     2018-10-24                       2215                       25671250                         25673325  Wednesday  67_Wednesday               0       0                       0         0      0      0      0            25673325           24  21231_25671250
# 24  020-88126765        NRML     False  DZ NRML-2             51228       4    13.7         13.7                     71  020-881267652018-10-23T08:00:00        2018-10-23 08:00:00          2018-10-25 02:00:00   1 days 18:00:00   2018-10-23 08:00:00  2018-10-25 02:00:00              71   BU CBD-1               00:26:00                 0                26                 0              00:15:00          0         15          0   BU CBD-1           00:17:00               00:50:00   BU CBD-1      7               0              17               0               0              50               0               0              17               0   2018-10-23     2018-10-25                       2520                       25671360                         25673742   Thursday   71_Thursday               0       0                       0         0      0      0      0            25673742           25  51228_25671360
# 25  020-30509732        NRML     False  DZ NRML-1             34842       5   121.7        121.7                      1  020-305097322018-10-24T16:05:00        2018-10-24 16:05:00          2018-10-30 05:00:00   5 days 12:55:00   2018-10-24 16:05:00  2018-10-30 05:00:00               1    BU FT-1               00:05:00                 0                 5                 0              00:15:00          0         15          0    BU FT-1           00:24:00               00:50:00    BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-24     2018-10-30                       7975                       25673285                         25681136    Tuesday     1_Tuesday               0       0                       0         0      0      0      0            25681136           26  34842_25673285
# 26  020-71669452        NRML     False  DZ NRML-1             34842       1     1.5          1.5                      1  020-716694522018-10-24T16:05:00        2018-10-24 16:05:00          2018-10-30 05:00:00   5 days 12:55:00   2018-10-24 16:05:00  2018-10-30 05:00:00               1    BU FT-1               00:05:00                 0                 5                 0              00:15:00          0         15          0    BU FT-1           00:24:00               00:50:00    BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-24     2018-10-30                       7975                       25673285                         25681136    Tuesday     1_Tuesday               0       0                       0         0      0      0      0            25681136           27  34842_25673285
# 27  020-47924671        NRML     False  DZ NRML-1             92870       1     7.9          7.9                      1  020-479246712018-10-23T06:00:00        2018-10-23 06:00:00          2018-10-24 05:00:00   0 days 23:00:00   2018-10-23 06:00:00  2018-10-24 05:00:00               1    BU FT-1               00:05:00                 0                 5                 0              00:15:00          0         15          0    BU FT-1           00:24:00               00:50:00    BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-23     2018-10-24                       1380                       25671240                         25672496  Wednesday   1_Wednesday               0       0                       0         0      0      0      0            25672496           28  92870_25671240
# 28  020-84082795        NRML     False  DZ NRML-1             92870       1   148.9        108.9                      1  020-840827952018-10-23T06:00:00        2018-10-23 06:00:00          2018-10-24 05:00:00   0 days 23:00:00   2018-10-23 06:00:00  2018-10-24 05:00:00               1    BU FT-1               00:05:00                 0                 5                 0              00:15:00          0         15          0    BU FT-1           00:24:00               00:50:00    BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-23     2018-10-24                       1380                       25671240                         25672496  Wednesday   1_Wednesday               0       0                       0         0      0      0      0            25672496           29  92870_25671240
# 29  020-83513404        NRML     False  DZ NRML-1             92870       1    14.9         14.9                      1  020-835134042018-10-23T06:00:00        2018-10-23 06:00:00          2018-10-24 05:00:00   0 days 23:00:00   2018-10-23 06:00:00  2018-10-24 05:00:00               1    BU FT-1               00:05:00                 0                 5                 0              00:15:00          0         15          0    BU FT-1           00:24:00               00:50:00    BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-23     2018-10-24                       1380                       25671240                         25672496  Wednesday   1_Wednesday               0       0                       0         0      0      0      0            25672496           30  92870_25671240
# 30  020-88126776         NML     False   DZ NML-1             51228       4    14.8         14.8                      1  020-881267762018-10-23T08:00:00        2018-10-23 08:00:00          2018-10-24 05:00:00   0 days 21:00:00   2018-10-23 08:00:00  2018-10-24 05:00:00               1    BU FT-1               00:05:00                 0                 5                 0              00:15:00          0         15          0    BU FT-1           00:24:00               00:50:00    BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-23     2018-10-24                       1260                       25671360                         25672496  Wednesday   1_Wednesday               0       0                       0         0      0      0      0            25672496           31  51228_25671360
# 31  020-81668646        NRML     False  DZ NRML-1             59243       1    10.9         10.9                      1  020-816686462018-10-23T12:50:00        2018-10-23 12:50:00          2018-10-24 05:00:00   0 days 16:10:00   2018-10-23 12:50:00  2018-10-24 05:00:00               1    BU FT-1               00:05:00                 0                 5                 0              00:15:00          0         15          0    BU FT-1           00:24:00               00:50:00    BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-23     2018-10-24                        970                       25671650                         25672496  Wednesday   1_Wednesday               0       0                       0         0      0      0      0            25672496           32  59243_25671650
# 32  020-88445335        NRML     False  DZ NRML-1             59243       1    11.8         11.8                      1  020-884453352018-10-24T12:50:00        2018-10-24 12:50:00          2018-10-25 05:00:00   0 days 16:10:00   2018-10-24 12:50:00  2018-10-25 05:00:00               1    BU FT-1               00:05:00                 0                 5                 0              00:15:00          0         15          0    BU FT-1           00:24:00               00:50:00    BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-24     2018-10-25                        970                       25673090                         25673936   Thursday    1_Thursday               0       0                       0         0      0      0      0            25673936           33  59243_25673090
# 33  020-81462220        NRML     False  DZ NRML-1             59243       1     3.1          3.1                      1  020-814622202018-10-24T17:05:00        2018-10-24 17:05:00          2018-10-30 05:00:00   5 days 11:55:00   2018-10-24 17:05:00  2018-10-30 05:00:00               1    BU FT-1               00:05:00                 0                 5                 0              00:15:00          0         15          0    BU FT-1           00:24:00               00:50:00    BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-24     2018-10-30                       7915                       25673345                         25681136    Tuesday     1_Tuesday               0       0                       0         0      0      0      0            25681136           34  59243_25673345
# 34  020-88156471        NRML     False  DZ NRML-1             49815       4     5.9          5.9                      1  020-881564712018-10-24T10:20:00        2018-10-24 10:20:00          2018-10-25 05:00:00   0 days 18:40:00   2018-10-24 10:20:00  2018-10-25 05:00:00               1    BU FT-1               00:05:00                 0                 5                 0              00:15:00          0         15          0    BU FT-1           00:24:00               00:50:00    BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-24     2018-10-25                       1120                       25672940                         25673936   Thursday    1_Thursday               0       0                       0         0      0      0      0            25673936           35  49815_25672940
# 35  020-30509743        NRML     False  DZ NRML-1             34842       3    12.6         12.6                     25  020-305097432018-10-24T16:05:00        2018-10-24 16:05:00          2018-10-25 02:20:00   0 days 10:15:00   2018-10-24 16:05:00  2018-10-25 02:20:00              25   BU NML-1               00:26:00                 0                26                 0              00:15:00          0         15          0   BU NML-1           00:13:00               00:40:00   BU NML-1      4               0              13               0               0              40               0               0              13               0   2018-10-24     2018-10-25                        615                       25673285                         25673776   Thursday   25_Thursday               0       0                       0         0      0      0      0            25673776           36  34842_25673285
# 36  020-30509721        NRML     False  DZ NRML-1             34842       1    83.7         83.7                     25  020-305097212018-10-24T16:05:00        2018-10-24 16:05:00          2018-10-25 02:20:00   0 days 10:15:00   2018-10-24 16:05:00  2018-10-25 02:20:00              25   BU NML-1               00:26:00                 0                26                 0              00:15:00          0         15          0   BU NML-1           00:13:00               00:40:00   BU NML-1      4               0              13               0               0              40               0               0              13               0   2018-10-24     2018-10-25                        615                       25673285                         25673776   Thursday   25_Thursday               0       0                       0         0      0      0      0            25673776           37  34842_25673285
# 37  020-84083624        NRML     False  DZ NRML-1             92870       1    45.6         45.6                     13  020-840836242018-10-23T06:00:00        2018-10-23 06:00:00          2018-10-25 11:30:00   2 days 05:30:00   2018-10-23 06:00:00  2018-10-25 11:30:00              13    BU FT-2               00:11:00                 0                11                 0              00:15:00          0         15          0    BU FT-2           00:24:00               00:45:00    BU FT-2      6               0              24               0               0              45               0               0              24               0   2018-10-23     2018-10-25                       3210                       25671240                         25674325   Thursday   13_Thursday               0       0                       0         0      0      0      0            25674325           38  92870_25671240
# 38  020-84111171        NRML     False  DZ NRML-1             92870       1    17.6         17.6                     13  020-841111712018-10-23T06:00:00        2018-10-23 06:00:00          2018-10-25 11:30:00   2 days 05:30:00   2018-10-23 06:00:00  2018-10-25 11:30:00              13    BU FT-2               00:11:00                 0                11                 0              00:15:00          0         15          0    BU FT-2           00:24:00               00:45:00    BU FT-2      6               0              24               0               0              45               0               0              24               0   2018-10-23     2018-10-25                       3210                       25671240                         25674325   Thursday   13_Thursday               0       0                       0         0      0      0      0            25674325           39  92870_25671240
# 39  020-84411515         NML     False   DZ NML-1             49815       1     1.5          1.5                     11  020-844115152018-10-25T10:20:00        2018-10-25 10:20:00          2018-10-25 20:55:00   0 days 10:35:00   2018-10-25 10:20:00  2018-10-25 20:55:00              11    BU FT-2               00:20:00                 0                20                 0              00:30:00          0         30          0    BU FT-2           00:24:00               00:45:00    BU FT-2      6               0              24               0               0              45               0               0              24               0   2018-10-25     2018-10-25                        635                       25674380                         25674866   Thursday   11_Thursday               0       0                       0         0      0      0      0            25674866           40  49815_25674380
# 40  020-84411526        NRML     False  DZ NRML-1             49815       4    40.1         40.1                     11  020-844115262018-10-25T10:20:00        2018-10-25 10:20:00          2018-10-25 20:55:00   0 days 10:35:00   2018-10-25 10:20:00  2018-10-25 20:55:00              11    BU FT-2               00:20:00                 0                20                 0              00:30:00          0         30          0    BU FT-2           00:24:00               00:45:00    BU FT-2      6               0              24               0               0              45               0               0              24               0   2018-10-25     2018-10-25                        635                       25674380                         25674866   Thursday   11_Thursday               0       0                       0         0      0      0      0            25674866           41  49815_25674380
# 41  020-88040466        NRML      True  DZ NRML-2             51228       4    28.8         28.8                     23  020-880404662018-10-23T08:00:00        2018-10-23 08:00:00          2018-10-24 20:00:00   1 days 12:00:00   2018-10-23 08:00:00  2018-10-24 20:00:00              23   BU NML-1               00:13:00                 0                13                 0              00:15:00          0         15          0   BU NML-1           00:13:00               00:40:00   BU NML-1      4               0              13               0               0              40               0               0              13               0   2018-10-23     2018-10-24                       2160                       25671360                         25673409  Wednesday  23_Wednesday               0       0                       0         0      0      0      0            25673409           42  51228_25671360
# 42  020-83895836         NML     False   DZ NML-1             59243       5    82.5         82.5                     48  020-838958362018-10-24T17:05:00        2018-10-24 17:05:00          2018-10-25 19:15:00   1 days 02:10:00   2018-10-24 17:05:00  2018-10-25 19:15:00              48  BU NRML-1               00:11:00                 0                11                 0              00:15:00          0         15          0  BU NRML-1           00:20:00               00:50:00  BU NRML-1      3               0              20               0               0              50               0               0              20               0   2018-10-24     2018-10-25                       1570                       25673345                         25674789   Thursday   48_Thursday               0       0                       0         0      0      0      0            25674789           43  59243_25673345

# %%
for i in ArrivalULDNumber_list:
    shipment_list = list(sample_shipments_bu[sample_shipments_bu.ArrivalULDNumber==i]['shipment_ID'])
    #print(shipment_list)
    for l in shipment_list:
        #print(int(i),str(j))
        number_of_ws = sample_shipments_bu[(sample_shipments_bu.ArrivalULDNumber==i) & (sample_shipments_bu.shipment_ID==l)]['Count'].unique()[0]
        shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.ArrivalULDNumber==i) & (sample_shipments_bu.shipment_ID==l)]['Shipment_departure_time_minutes'].unique()[0]
        bu_zone_name = sample_shipments_bu[(sample_shipments_bu.ArrivalULDNumber==i) & (sample_shipments_bu.shipment_ID==l)]['Name_x'].unique()[0]
        flight_number = sample_shipments_bu[(sample_shipments_bu.ArrivalULDNumber==i) & (sample_shipments_bu.shipment_ID==l)]['FlightNumberDeparture'].unique()[0]
        for m in range(1,number_of_ws+1):
            for t in range(shipment_departure_time_minutes_loop-60, shipment_departure_time_minutes_loop):
                if z[l,m,t].x > 0.5:
                    k = str(bu_zone_name +"-WS-" + str(m))
                    #print("Shipment", l, "assigned to", bu_zone_name,"WS",m, "at", t)
                    plt.plot(t, k, "o")
                    #plt.annotate(l, (t,k))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#################################################################################################################################
#################################################################################################################################
#################################################################################################################################

# %%
df_final_x = []
for i in uld_uniqueid_list:
    BreakDownZoneName_list1 = list(df_merge1[df_merge1.unique_id==i]['BreakDownZoneName'])
    #print(i, "in", BreakDownZoneName_list1)
    for j in BreakDownZoneName_list1:
        #print(int(i),str(j))
        new_check = df_merge1[(df_merge1.unique_id==i) & (df_merge1.BreakDownZoneName==j)]
        shipment_arrival_time_minutes_loop = list(new_check['Shipment_arrival_time_minutes'].unique())[0]
        shipment_arrival_duation_minutes_loop = list(new_check['one_hour_duration'].unique())[0] #list(new_check['Shipment_duration_minutes'].unique())[0]
        for k in range((min(list(df_merge1[df_merge1.BreakDownZoneName==j]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((shipment_arrival_time_minutes_loop-min(list(df_merge1[df_merge1.BreakDownZoneName==j]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==j].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==j].iloc[0]['handling_m']))), (min(list(df_merge1[df_merge1.BreakDownZoneName==j]['Shipment_arrival_time_minutes'].unique())) + (math.ceil((shipment_arrival_time_minutes_loop-min(list(df_merge1[df_merge1.BreakDownZoneName==j]['Shipment_arrival_time_minutes'].unique())))/(df_merge1[df_merge1.BreakDownZoneName==j].iloc[0]['handling_m']))*(df_merge1[df_merge1.BreakDownZoneName==j].iloc[0]['handling_m']))) +shipment_arrival_duation_minutes_loop, df_merge1[df_merge1.BreakDownZoneName==j].iloc[0]['handling_m']):
            if x[i,j,k].x > 0.5:
                df_final_x.append((i, j, k))


df_final_x1 = pd.DataFrame(df_final_x, columns=('unique_id', 'bd_name', 'assigned_time'))

# %%
df_final_x1.head()
# Out:
#         unique_id    bd_name  assigned_time
# 0  21231_25671250  BD NRML-4       25671312
# 1  21231_25671250   BD NML-3       25671280
# 2  24321_25671250  BD NRML-1       25671270
# 3  42309_25671550  BD NRML-1       25671570
# 4  49809_25673105  BD NRML-4       25673119

# %%
df_final_x1.to_csv(r'./output/bd_assigned_time_output.csv')

# %%
df_final_z = []
for i in ArrivalULDNumber_list:
    shipment_list = list(sample_shipments_bu[sample_shipments_bu.ArrivalULDNumber==i]['shipment_ID'])
    #print(shipment_list)
    for l in shipment_list:
        #print(int(i),str(j))
        number_of_ws = sample_shipments_bu[(sample_shipments_bu.ArrivalULDNumber==i) & (sample_shipments_bu.shipment_ID==l)]['Count'].unique()[0]
        shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.ArrivalULDNumber==i) & (sample_shipments_bu.shipment_ID==l)]['Shipment_departure_time_minutes'].unique()[0]
        bu_zone_name = sample_shipments_bu[(sample_shipments_bu.ArrivalULDNumber==i) & (sample_shipments_bu.shipment_ID==l)]['Name_x'].unique()[0]
        flight_number = sample_shipments_bu[(sample_shipments_bu.ArrivalULDNumber==i) & (sample_shipments_bu.shipment_ID==l)]['FlightNumberDeparture'].unique()[0]
        for m in range(1,number_of_ws+1):
            for t in range(shipment_departure_time_minutes_loop-60, shipment_departure_time_minutes_loop):
                if z[l,m,t].x > 0.5:
                    #k = str(bu_zone_name +"-WS-" + str(m))
                    df_final_z.append((l,bu_zone_name ,m, t))

df_final_z = pd.DataFrame(df_final_z, columns=('shipment_id', 'bu_name', 'ws_number', 'buildup_time'))

# %%
df_final_z.head()
# Out:
#    shipment_id    bu_name  ws_number  buildup_time
# 0            1    BU FT-1          3      25673872
# 1            7    BU FT-1          3      25677252
# 2           21    BU FT-2          1      25673412
# 3           30    BU FT-2          3      25677499
# 4           36  BU NRML-1          1      25673505

# %%
df_final_z.to_csv(r'./output/bu_workstation_time_output.csv')

# %%
sample_shipments.to_csv(r'./output/sample_shipments.csv')
sample_shipments_bu.to_csv(r'./output/sample_shipments_bu.csv')
booking_new.to_csv(r'./output/booking_new.csv')
booking_new_BU.to_csv(r'./output/booking_new_BU.csv')
df_merge1.to_csv(r'./output/df_merge1.csv')
two_drop_zones.to_csv(r'./output/two_drop_zones.csv')
new.to_csv(r'./output/new.csv')
bu_zone_all.to_csv(r'./output/bu_zone_all.csv')
uld_bd_data.to_csv(r'./output/uld_bd_data.csv')
bu_workstation_count.to_csv(r'./output/bu_workstation_count.csv')
uld_bd_data.to_csv(r'./output/uld_bd_data.csv')
dz_ship_data.to_csv(r'./output/dz_ship_data.csv')
dz_to_bd.to_csv(r'./output/dz_to_bd.csv')
multiple_uld_number_and_times.to_csv(r'./output/multiple_uld_number_and_times.csv')
unique_uld_count_by_number.to_csv(r'./output/unique_uld_count_by_number.csv')
flight_pre_processing_all.to_csv(r'./output/flight_pre_processing_all.csv')
flight_default_processing.to_csv(r'./output/flight_default_processing.csv')
uld_number_times.to_csv(r'./output/uld_number_times.csv')
bu_zones_to_flight.to_csv(r'./output/bu_zones_to_flight.csv')
bd_zones.to_csv(r'./output/bd_zones.csv')
bd_capacity.to_csv(r'./output/bd_capacity.csv')

# %%
for k in filghts_list:
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.FlightNumberDeparture==k]['departure_date'].unique())
    for d in shipment_date_list:
        ws_list = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Count'].unique()[0]
        shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_departure_time_minutes'].unique()[0]
    #print(shipment_list)
        for m in range(1, ws_list+1):
        #print(int(i),str(j))
            for t in range(shipment_departure_time_minutes_loop-60, shipment_departure_time_minutes_loop):
                if q[k,m,t].x > 0.5:
                    print("Flight", k, "WS open", m, "at", t)
# Out:
# Flight 3 WS open 3 at 25673872
# Flight 4 WS open 1 at 25677252
# Flight 4 WS open 2 at 25677252
# Flight 4 WS open 3 at 25677252
# Flight 7 WS open 1 at 25673412
# Flight 9 WS open 3 at 25677499
# Flight 46 WS open 1 at 25673505
# Flight 60 WS open 2 at 25675414
# Flight 61 WS open 3 at 25674397
# Flight 62 WS open 1 at 25673537
# Flight 63 WS open 1 at 25676163
# Flight 64 WS open 1 at 25676983
# Flight 64 WS open 2 at 25676983
# Flight 65 WS open 3 at 25674669
# Flight 66 WS open 1 at 25677353
# Flight 66 WS open 2 at 25677353
# Flight 66 WS open 3 at 25677353
# Flight 67 WS open 1 at 25673265
# Flight 68 WS open 2 at 25674423
# Flight 68 WS open 3 at 25674423
# Flight 69 WS open 2 at 25676159
# Flight 69 WS open 3 at 25676159
# Flight 70 WS open 1 at 25674912
# Flight 71 WS open 1 at 25673682
# Flight 71 WS open 2 at 25673682
# Flight 71 WS open 3 at 25673682
# Flight 72 WS open 2 at 25674560
# Flight 73 WS open 1 at 25674977
# Flight 73 WS open 2 at 25674977
# Flight 73 WS open 3 at 25674977
# Flight 74 WS open 1 at 25671844
# Flight 75 WS open 1 at 25673355
# Flight 76 WS open 1 at 25673272
# Flight 77 WS open 1 at 25673340
# Flight 78 WS open 1 at 25675103
# Flight 79 WS open 2 at 25675885
# Flight 82 WS open 3 at 25674399
# Flight 1 WS open 1 at 25672436
# Flight 1 WS open 2 at 25672436
# Flight 1 WS open 3 at 25672436
# Flight 1 WS open 3 at 25672469
# Flight 1 WS open 3 at 25672470
# Flight 1 WS open 3 at 25672471
# Flight 1 WS open 1 at 25673876
# Flight 1 WS open 2 at 25673876
# Flight 1 WS open 3 at 25673876
# Flight 1 WS open 1 at 25681076
# Flight 1 WS open 2 at 25681076
# Flight 1 WS open 3 at 25681076
# Flight 1 WS open 3 at 25681106
# Flight 1 WS open 3 at 25681107
# Flight 1 WS open 3 at 25681108
# Flight 1 WS open 3 at 25681109
# Flight 1 WS open 3 at 25681110
# Flight 1 WS open 3 at 25681111
# Flight 2 WS open 2 at 25673740
# Flight 25 WS open 1 at 25673716
# Flight 25 WS open 1 at 25673761
# Flight 25 WS open 1 at 25673762
# Flight 25 WS open 2 at 25673716
# Flight 25 WS open 3 at 25673716
# Flight 25 WS open 3 at 25673762
# Flight 5 WS open 2 at 25675661
# Flight 5 WS open 3 at 25675661
# Flight 8 WS open 2 at 25674846
# Flight 13 WS open 3 at 25674265
# Flight 81 WS open 3 at 25673942
# Flight 6 WS open 3 at 25674236
# Flight 10 WS open 2 at 25673246
# Flight 11 WS open 3 at 25674806
# Flight 12 WS open 2 at 25673955
# Flight 14 WS open 1 at 25672584
# Flight 15 WS open 2 at 25673405
# Flight 16 WS open 1 at 25673396
# Flight 18 WS open 2 at 25673939
# Flight 21 WS open 2 at 25673830
# Flight 21 WS open 3 at 25673830
# Flight 22 WS open 1 at 25674037
# Flight 28 WS open 2 at 25673295
# Flight 27 WS open 1 at 25674734
# Flight 27 WS open 2 at 25674734
# Flight 27 WS open 3 at 25674734
# Flight 29 WS open 3 at 25673310
# Flight 34 WS open 1 at 25673506
# Flight 31 WS open 1 at 25674980
# Flight 31 WS open 1 at 25675026
# Flight 31 WS open 2 at 25674980
# Flight 31 WS open 3 at 25674980
# Flight 32 WS open 2 at 25674367
# Flight 80 WS open 1 at 25673921
# Flight 80 WS open 2 at 25673921
# Flight 80 WS open 3 at 25673921
# Flight 36 WS open 3 at 25675677
# Flight 23 WS open 1 at 25673349
# Flight 33 WS open 2 at 25674075
# Flight 35 WS open 3 at 25673484
# Flight 43 WS open 2 at 25674265
# Flight 54 WS open 1 at 25674841
# Flight 17 WS open 1 at 25673912
# Flight 42 WS open 1 at 25673376
# Flight 40 WS open 1 at 25673210
# Flight 44 WS open 2 at 25673813
# Flight 45 WS open 1 at 25676200
# Flight 30 WS open 2 at 25674106
# Flight 30 WS open 3 at 25674106
# Flight 57 WS open 3 at 25674850
# Flight 48 WS open 2 at 25674729
# Flight 48 WS open 3 at 25674729
# Flight 47 WS open 1 at 25673089
# Flight 19 WS open 2 at 25679663
# Flight 19 WS open 3 at 25679663
# Flight 38 WS open 3 at 25672503
# Flight 52 WS open 2 at 25673160
# Flight 52 WS open 3 at 25673160
# Flight 41 WS open 3 at 25673540
# Flight 20 WS open 2 at 25674286
# Flight 37 WS open 1 at 25673056
# Flight 56 WS open 1 at 25676358
# Flight 58 WS open 3 at 25674737
# Flight 24 WS open 2 at 25674481
# Flight 53 WS open 2 at 25680782
# Flight 59 WS open 1 at 25672504
# Flight 49 WS open 3 at 25675563
# Flight 50 WS open 1 at 25674733
# Flight 50 WS open 2 at 25674733
# Flight 50 WS open 3 at 25674733
# Flight 51 WS open 3 at 25676029
# Flight 39 WS open 2 at 25671958

# %%
for k in filghts_list:
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.FlightNumberDeparture==k]['departure_date'].unique())
    for d in shipment_date_list:
        ws_list = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Count'].unique()[0]
        shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_departure_time_minutes'].unique()[0]
    #print(shipment_list)
        for m in range(1, ws_list+1):
        #print(int(i),str(j))
            for t in range(shipment_departure_time_minutes_loop-60, shipment_departure_time_minutes_loop):
                if q[k,m,t].x > 0.5:
                    plt.plot(t, k, "o")
                    #plt.annotate(k, (t,k))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df_final_q = []
for k in filghts_list:
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.FlightNumberDeparture==k]['departure_date'].unique())
    for d in shipment_date_list:
        ws_list = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Count'].unique()[0]
        shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_departure_time_minutes'].unique()[0]
        bu_zone_name = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Name_x'].unique()[0]
    #print(shipment_list)
        for m in range(1, ws_list+1):
        #print(int(i),str(j))
            for t in range(shipment_departure_time_minutes_loop-60, shipment_departure_time_minutes_loop):
                if q[k,m,t].x > 0.5:
                    df_final_q.append((k,bu_zone_name ,m, t))

df_final_q = pd.DataFrame(df_final_q, columns=('flight_number', 'bu_name', 'ws_number', 'ws_open_time'))

# %%
df_final_q['ws_open_date_time'] = pd.to_datetime(df_final_q['ws_open_time'], unit='m')

# %%
df_final_q.to_csv(r'./output/q_ws_open_for_flight.csv')

# %%
##############################################################################################

# %%
model = Model('BU zone model 2')

# %%
start = {}
for k in filghts_list:
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.FlightNumberDeparture==k]['departure_date'].unique())
    for d in shipment_date_list:
        ws_list = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Count'].unique()[0]
        shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_departure_time_minutes'].unique()[0]
        shipment_arrival_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_arrival_time_minutes'].unique()[0]
        bu_handling_time = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['handling_ULD_m'].unique()[0]
        for t in range((shipment_departure_time_minutes_loop - 60), shipment_departure_time_minutes_loop):
            start[k,t] = model.addVar(vtype=GRB.INTEGER)

# %%
offload_table = pd.pivot_table(sample_shipments_bu, values='TotalWeight', index=['FlightNumberDeparture', 'Name_x', 'departure_date'], aggfunc=np.sum, fill_value=0).reset_index()
offload_table['ULD scheduled'] = (offload_table['TotalWeight']/400)
offload_table['ULD scheduled'] = offload_table['ULD scheduled'].apply(lambda x: math.ceil(x))
offload_table.head()
# Out:
#    FlightNumberDeparture   Name_x departure_date  TotalWeight  ULD scheduled
# 0                      1  BU FT-1     2018-10-24        157.4              1
# 1                      1  BU FT-1     2018-10-25         17.7              1
# 2                      1  BU FT-1     2018-10-30        126.3              1
# 3                      3  BU FT-1     2018-10-25         26.2              1
# 4                      4  BU FT-1     2018-10-27          5.5              1

# %%
offload = {}
for k in filghts_list:
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.FlightNumberDeparture==k]['departure_date'].unique())
    for d in shipment_date_list:
        offload[k,d] = model.addVar(vtype=GRB.INTEGER)

# %%
dead = {}
for k in filghts_list:
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.FlightNumberDeparture==k]['departure_date'].unique())
    for d in shipment_date_list:
        ws_list = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Count'].unique()[0]
        shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_departure_time_minutes'].unique()[0]
        shipment_arrival_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_arrival_time_minutes'].unique()[0]
        bu_handling_time = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['handling_ULD_m'].unique()[0]
        for t in range((shipment_departure_time_minutes_loop - 60), shipment_departure_time_minutes_loop):
            dead[k,t] = model.addVar(vtype=GRB.CONTINUOUS, ub = 400, lb = 0)

# %%
for k in filghts_list:
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.FlightNumberDeparture==k]['departure_date'].unique())
    for d in shipment_date_list:
        shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_departure_time_minutes'].unique()[0]
        uld_k = offload_table[(offload_table.FlightNumberDeparture==k) & (offload_table.departure_date==d)].iloc[0]['ULD scheduled']
        #print(k,"--",d)
        model.addConstr(quicksum(start[k,t] for t in range((shipment_departure_time_minutes_loop - 60), shipment_departure_time_minutes_loop)) == (uld_k - (offload[k,d])))

# %%
pack={}
for k in filghts_list:
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.FlightNumberDeparture==k]['departure_date'].unique())
    for d in shipment_date_list:
        ws_list = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Count'].unique()[0]
        shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_departure_time_minutes'].unique()[0]
        shipment_arrival_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_arrival_time_minutes'].unique()[0]
        bu_handling_time = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['handling_ULD_m'].unique()[0]
        for t in range((shipment_departure_time_minutes_loop - 60), shipment_departure_time_minutes_loop):
            pack[k,t] = model.addVar(vtype=GRB.INTEGER)

# %%
for k in filghts_list:
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.FlightNumberDeparture==k]['departure_date'].unique())
    for d in shipment_date_list:
        ws_list = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Count'].unique()[0]
        shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_departure_time_minutes'].unique()[0]
        shipment_arrival_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_arrival_time_minutes'].unique()[0]
        bu_handling_time = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['handling_ULD_m'].unique()[0]
        for t in range((shipment_departure_time_minutes_loop - 60), shipment_departure_time_minutes_loop):
            if(t==(shipment_departure_time_minutes_loop - 60)):
                model.addConstr(pack[k,t]==0)
            else:
                model.addConstr(pack[k,t] == pack[k,t-1] + start[k,t]*400 -  dead[k,t])

# %%
for k in filghts_list:
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.FlightNumberDeparture==k]['departure_date'].unique())
    for d in shipment_date_list:
        ws_list = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Count'].unique()[0]
        shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_departure_time_minutes'].unique()[0]
        shipment_arrival_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_arrival_time_minutes'].unique()[0]
        bu_handling_time = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['handling_ULD_m'].unique()[0]
        for t in range((shipment_departure_time_minutes_loop - 60), shipment_departure_time_minutes_loop):
            avail_t = pd.pivot_table(sample_shipments_bu, values='TotalWeight', index=['FlightNumberDeparture', 'departure_date'], aggfunc=np.sum, fill_value=0).reset_index()
            avail_kt = avail_t[(avail_t.FlightNumberDeparture==k) & (avail_t.departure_date==d)].iloc[0]['TotalWeight']
            model.addConstr(pack[k,t] <= avail_kt)

# %%
for k in filghts_list:
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.FlightNumberDeparture==k]['departure_date'].unique())
    for d in shipment_date_list:
        split = offload_table[(offload_table.FlightNumberDeparture==k) & (offload_table.departure_date==d)].iloc[0]['ULD scheduled']
        shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_departure_time_minutes'].unique()[0]
        shipment_arrival_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_arrival_time_minutes'].unique()[0]
        bu_handling_time = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['handling_ULD_m'].unique()[0]
        for t in range((shipment_departure_time_minutes_loop - 60 + bu_handling_time), shipment_departure_time_minutes_loop):
            model.addConstr(quicksum(start[k,ta] for ta in range((t-bu_handling_time),t))<=split)

# %%
time=[]
for b in bu_zones_list:
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.Name_x==b]['departure_date'].unique())
    open_t = sample_shipments_bu[(sample_shipments_bu.Name_x==b)]['Count'].unique()[0]
    for d in shipment_date_list:
        bu_flights_list = list(sample_shipments_bu[(sample_shipments_bu.Name_x==b) & (sample_shipments_bu.departure_date==d)]['FlightNumberDeparture'].unique())
        for k in bu_flights_list:
            shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_departure_time_minutes'].unique()[0]
            time.append(shipment_departure_time_minutes_loop)
            
        for t in range((min(time) - 60), max(time)):
            uld_list1=[]
            for i in bu_flights_list:
                if(t in range((sample_shipments_bu[sample_shipments_bu.FlightNumberDeparture==i].iloc[0]['Shipment_departure_time_minutes']-60),sample_shipments_bu[sample_shipments_bu.FlightNumberDeparture==i].iloc[0]['Shipment_departure_time_minutes'])):
                    uld_list1.append(i) 
                
            model.addConstr(quicksum(start[k,ta] for k in uld_list1 for ta in range((max(t,t-sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k)].iloc[0]['handling_ULD_m'])),t))<=open_t)

# %%
obj=0
for k in filghts_list:
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.FlightNumberDeparture==k]['departure_date'].unique())
    for d in shipment_date_list:
        ws_list = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Count'].unique()[0]
        shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_departure_time_minutes'].unique()[0]
        shipment_arrival_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_arrival_time_minutes'].unique()[0]
        bu_handling_time = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['handling_ULD_m'].unique()[0]
        for t in range((shipment_departure_time_minutes_loop - 60), shipment_departure_time_minutes_loop):
            obj += dead[k,t]

# %%
for k in filghts_list:
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.FlightNumberDeparture==k]['departure_date'].unique())
    for d in shipment_date_list:
        obj += 400*offload[k,d]

# %%
model.setObjective(obj, GRB.MINIMIZE)

# %%
model.optimize()
# Out:
# Optimize a model with 127391 rows, 3982 columns and 25605 nonzeros
# Variable types: 1320 continuous, 2662 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [1e+00, 4e+02]
#   Bounds range     [4e+02, 4e+02]
#   RHS range        [3e-01, 3e+02]
# Found heuristic solution: objective 8800.0000000
# Presolve removed 127331 rows and 3806 columns
# Presolve time: 0.11s
# Presolved: 60 rows, 176 columns, 293 nonzeros
# Found heuristic solution: objective 0.0000000
# Variable types: 0 continuous, 176 integer (59 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.16 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%

# %%
for k in filghts_list:
    shipment_date_list = list(sample_shipments_bu[sample_shipments_bu.FlightNumberDeparture==k]['departure_date'].unique())
    for d in shipment_date_list:
        ws_list = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Count'].unique()[0]
        shipment_departure_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_departure_time_minutes'].unique()[0]
        shipment_arrival_time_minutes_loop = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['Shipment_arrival_time_minutes'].unique()[0]
        bu_handling_time = sample_shipments_bu[(sample_shipments_bu.FlightNumberDeparture==k) & (sample_shipments_bu.departure_date==d)]['handling_ULD_m'].unique()[0]
        for t in range((shipment_departure_time_minutes_loop - 60), shipment_departure_time_minutes_loop):
            if start[k,t].x > 0.5:
                    print("Flight", k, "start at", t)
# Out:
# Flight 3 start at 25673872
# Flight 4 start at 25677252
# Flight 7 start at 25673412
# Flight 9 start at 25677499
# Flight 46 start at 25673505
# Flight 60 start at 25675414
# Flight 61 start at 25674397
# Flight 62 start at 25673537
# Flight 63 start at 25676163
# Flight 64 start at 25676983
# Flight 65 start at 25674669
# Flight 66 start at 25677353
# Flight 67 start at 25673265
# Flight 71 start at 25673682
# Flight 1 start at 25681076
# Flight 1 start at 25672436
# Flight 1 start at 25673876
# Flight 25 start at 25673716
# Flight 13 start at 25674265
# Flight 11 start at 25674806
# Flight 23 start at 25673349
# Flight 48 start at 25674729

# %%
sample_shipments_bu[sample_shipments_bu.FlightNumberDeparture==1]
# Out:
#      Shipment ID ProductName  Priority   DropZone  ArrivalULDNumber  Pieces  Weight  TotalWeight  FlightNumberDeparture     key_shipment_id_arrival_date Shipment_arrival_date_time Shipment_departure_date_time Shipment_duration build_up_arrival_time build_up_finish_time  FlightNumber_x  BU Zone TransportationDistance  transport_dist_h  transport_dist_m  transport_dist_s DefaultProcessingTime  default_h  default_m  default_s   Name_x HandlingTimePerULD TransportationTimeToWH   Name_y  Count  handling_ULD_h  handling_ULD_m  handling_ULD_s  transport_WH_h  transport_WH_m  transport_WH_s  ULD_handling_h  ULD_handling_m  ULD_handling_s arrival_date departure_date  Shipment_duration_minutes  Shipment_arrival_time_minutes  Shipment_departure_time_minutes   day_name flight_pre_id  FlightNumber_y Weekday PreProcessingBufferTime day  Pre_h  Pre_m  Pre_s  new_departure_time  shipment_ID       unique_id
# 25  020-30509732        NRML     False  DZ NRML-1             34842       5   121.7        121.7                      1  020-305097322018-10-24T16:05:00        2018-10-24 16:05:00          2018-10-30 05:00:00   5 days 12:55:00   2018-10-24 16:05:00  2018-10-30 05:00:00               1  BU FT-1               00:05:00                 0                 5                 0              00:15:00          0         15          0  BU FT-1           00:24:00               00:50:00  BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-24     2018-10-30                       7975                       25673285                         25681136    Tuesday     1_Tuesday               0       0                       0   0      0      0      0            25681136           26  34842_25673285
# 26  020-71669452        NRML     False  DZ NRML-1             34842       1     1.5          1.5                      1  020-716694522018-10-24T16:05:00        2018-10-24 16:05:00          2018-10-30 05:00:00   5 days 12:55:00   2018-10-24 16:05:00  2018-10-30 05:00:00               1  BU FT-1               00:05:00                 0                 5                 0              00:15:00          0         15          0  BU FT-1           00:24:00               00:50:00  BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-24     2018-10-30                       7975                       25673285                         25681136    Tuesday     1_Tuesday               0       0                       0   0      0      0      0            25681136           27  34842_25673285
# 27  020-47924671        NRML     False  DZ NRML-1             92870       1     7.9          7.9                      1  020-479246712018-10-23T06:00:00        2018-10-23 06:00:00          2018-10-24 05:00:00   0 days 23:00:00   2018-10-23 06:00:00  2018-10-24 05:00:00               1  BU FT-1               00:05:00                 0                 5                 0              00:15:00          0         15          0  BU FT-1           00:24:00               00:50:00  BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-23     2018-10-24                       1380                       25671240                         25672496  Wednesday   1_Wednesday               0       0                       0   0      0      0      0            25672496           28  92870_25671240
# 28  020-84082795        NRML     False  DZ NRML-1             92870       1   148.9        108.9                      1  020-840827952018-10-23T06:00:00        2018-10-23 06:00:00          2018-10-24 05:00:00   0 days 23:00:00   2018-10-23 06:00:00  2018-10-24 05:00:00               1  BU FT-1               00:05:00                 0                 5                 0              00:15:00          0         15          0  BU FT-1           00:24:00               00:50:00  BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-23     2018-10-24                       1380                       25671240                         25672496  Wednesday   1_Wednesday               0       0                       0   0      0      0      0            25672496           29  92870_25671240
# 29  020-83513404        NRML     False  DZ NRML-1             92870       1    14.9         14.9                      1  020-835134042018-10-23T06:00:00        2018-10-23 06:00:00          2018-10-24 05:00:00   0 days 23:00:00   2018-10-23 06:00:00  2018-10-24 05:00:00               1  BU FT-1               00:05:00                 0                 5                 0              00:15:00          0         15          0  BU FT-1           00:24:00               00:50:00  BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-23     2018-10-24                       1380                       25671240                         25672496  Wednesday   1_Wednesday               0       0                       0   0      0      0      0            25672496           30  92870_25671240
# 30  020-88126776         NML     False   DZ NML-1             51228       4    14.8         14.8                      1  020-881267762018-10-23T08:00:00        2018-10-23 08:00:00          2018-10-24 05:00:00   0 days 21:00:00   2018-10-23 08:00:00  2018-10-24 05:00:00               1  BU FT-1               00:05:00                 0                 5                 0              00:15:00          0         15          0  BU FT-1           00:24:00               00:50:00  BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-23     2018-10-24                       1260                       25671360                         25672496  Wednesday   1_Wednesday               0       0                       0   0      0      0      0            25672496           31  51228_25671360
# 31  020-81668646        NRML     False  DZ NRML-1             59243       1    10.9         10.9                      1  020-816686462018-10-23T12:50:00        2018-10-23 12:50:00          2018-10-24 05:00:00   0 days 16:10:00   2018-10-23 12:50:00  2018-10-24 05:00:00               1  BU FT-1               00:05:00                 0                 5                 0              00:15:00          0         15          0  BU FT-1           00:24:00               00:50:00  BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-23     2018-10-24                        970                       25671650                         25672496  Wednesday   1_Wednesday               0       0                       0   0      0      0      0            25672496           32  59243_25671650
# 32  020-88445335        NRML     False  DZ NRML-1             59243       1    11.8         11.8                      1  020-884453352018-10-24T12:50:00        2018-10-24 12:50:00          2018-10-25 05:00:00   0 days 16:10:00   2018-10-24 12:50:00  2018-10-25 05:00:00               1  BU FT-1               00:05:00                 0                 5                 0              00:15:00          0         15          0  BU FT-1           00:24:00               00:50:00  BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-24     2018-10-25                        970                       25673090                         25673936   Thursday    1_Thursday               0       0                       0   0      0      0      0            25673936           33  59243_25673090
# 33  020-81462220        NRML     False  DZ NRML-1             59243       1     3.1          3.1                      1  020-814622202018-10-24T17:05:00        2018-10-24 17:05:00          2018-10-30 05:00:00   5 days 11:55:00   2018-10-24 17:05:00  2018-10-30 05:00:00               1  BU FT-1               00:05:00                 0                 5                 0              00:15:00          0         15          0  BU FT-1           00:24:00               00:50:00  BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-24     2018-10-30                       7915                       25673345                         25681136    Tuesday     1_Tuesday               0       0                       0   0      0      0      0            25681136           34  59243_25673345
# 34  020-88156471        NRML     False  DZ NRML-1             49815       4     5.9          5.9                      1  020-881564712018-10-24T10:20:00        2018-10-24 10:20:00          2018-10-25 05:00:00   0 days 18:40:00   2018-10-24 10:20:00  2018-10-25 05:00:00               1  BU FT-1               00:05:00                 0                 5                 0              00:15:00          0         15          0  BU FT-1           00:24:00               00:50:00  BU FT-1      5               0              24               0               0              50               0               0              24               0   2018-10-24     2018-10-25                       1120                       25672940                         25673936   Thursday    1_Thursday               0       0                       0   0      0      0      0            25673936           35  49815_25672940

# %%
1076+60
# Out:
# 1136
